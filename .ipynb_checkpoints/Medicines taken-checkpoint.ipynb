# %%
from IPython.display import display
from matplotlib.ticker import StrMethodFormatter
from matplotlib.ticker import FormatStrFormatter

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re
import spacy

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.set_option('display.max_colwidth', None)

# %matplotlib inline

# %%
#for text pre-processing
import re, string
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')
#for model-building
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, f1_score, accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, auc, roc_auc_score
# bag of words
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
#for word embedding
import gensim
from gensim.models import Word2Vec

wl = WordNetLemmatizer()
snow = SnowballStemmer('english')
# Out:
# [nltk_data] Downloading package punkt to /home/mikes/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/mikes/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/mikes/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/mikes/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
 # %cat '/home/mikes/nltk_data/corpora/stopwords/english'
# Out:
# mg
# mgs
# milligram
# milligrams
# i
# me
# my
# myself
# we
# our
# ours
# ourselves
# you
# you're
# you've
# you'll
# you'd
# your
# yours
# yourself
# yourselves
# he
# him
# his
# himself
# she
# she's
# her
# hers
# herself
# it
# it's
# its
# itself
# they
# them
# their
# theirs
# themselves
# what
# which
# who
# whom
# this
# that
# that'll
# these
# those
# am
# is
# are
# was
# were
# be
# been
# being
# have
# has
# had
# having
# do
# does
# did
# doing
# a
# an
# the
# and
# but
# if
# or
# because
# as
# until
# while
# of
# at
# by
# for
# with
# about
# against
# between
# into
# through
# during
# before
# after
# above
# below
# to
# from
# up
# down
# in
# out
# on
# off
# over
# under
# again
# further
# then
# once
# here
# there
# when
# where
# why
# how
# all
# any
# both
# each
# few
# more
# most
# other
# some
# such
# no
# nor
# not
# only
# own
# same
# so
# than
# too
# very
# s
# t
# can
# will
# just
# don
# don't
# should
# should've
# now
# d
# ll
# m
# o
# re
# ve
# y
# ain
# aren
# aren't
# couldn
# couldn't
# didn
# didn't
# doesn
# doesn't
# hadn
# hadn't
# hasn
# hasn't
# haven
# haven't
# isn
# isn't
# ma
# mightn
# mightn't
# mustn
# mustn't
# needn
# needn't
# shan
# shan't
# shouldn
# shouldn't
# wasn
# wasn't
# weren
# weren't
# won
# won't
# wouldn
# wouldn't

# %%
dir = "/home/mikes/Documents/jupyterEnvironments/VAERS_analysis/"
file = "VAERS data deaths only Edited for NLP.csv"
#file = "VAERS data deaths only Edited for NLP for HAD COVID.csv"
path = os.path.join(dir, file)

vd = pd.read_csv(path, 
                 delimiter = ",", 
                 encoding = "ISO-8859-1")
vd.columns
# Out:
# Index(['VAERS_ID', 'SYMPTOM_TEXT_TARGET', 'HOSPICE_TARGET', 'RECVDATE',
#        'STATE', 'AGE_YRS', 'CAGE_YR', 'CAGE_MO', 'SEX', 'RPT_DATE',
#        'SYMPTOM_TEXT', 'DIED', 'DATEDIED', 'L_THREAT', 'ER_VISIT', 'HOSPITAL',
#        'HOSPDAYS', 'X_STAY', 'DISABLE', 'RECOVD', 'VAX_DATE', 'ONSET_DATE',
#        'NUMDAYS', 'LAB_DATA', 'V_ADMINBY', 'V_FUNDBY', 'OTHER_MEDS',
#        'OTHER_MEDS_TARGET', 'CUR_ILL', 'CUR_ILL_TARGET', 'HISTORY',
#        'HISTORY_TARGET', 'PRIOR_VAX', 'SPLTTYPE', 'FORM_VERS', 'TODAYS_DATE',
#        'BIRTH_DEFECT', 'OFC_VISIT', 'ER_ED_VISIT', 'ALLERGIES'],
#       dtype='object')

# %%
#convert to lowercase and remove punctuations and characters and then strip
def preprocess(text):
    text = text.lower() #lowercase text
    text=text.strip()  #get rid of leading/trailing whitespace 
    text=re.compile('<.*?>').sub('', text) #Remove HTML tags/markups
    text = re.compile('[%s]' % re.escape(string.punctuation)).sub(' ', text)  #Replace punctuation with space. Careful since punctuation can sometime be useful
    text = re.sub('\s+', ' ', text)  #Remove extra space and tabs
    text = re.sub(r'\[[0-9]*\]',' ',text) #[0-9] matches any digit (0 to 10000...)
    text=re.sub(r'[^\w\s]', '', str(text).lower().strip())
    text = re.sub(r'\d',' ',text) #matches any digit from 0 to 100000..., \D matches non-digits
    text = re.sub(r'\s+',' ',text) #\s matches any whitespace, \s+ matches multiple whitespace, \S matches non-whitespace 
    
    return text

#1a. STOPWORD REMOVAL
def stopword(string):
    a= [i for i in string.split() if i not in stopwords.words('english')]
    return ' '.join(a)

#1b. STOPWORD REMOVAL
def stopword_medications(string):
    """
    Additional stopwords specific to medications added to text file "/home/mikes/nltk_data/corpora/stopwords/english.medications"
    """
    a= [i for i in string.split() if i not in stopwords.words('english.medications')]
    return ' '.join(a)

#2. STEMMING 
# Initialize the stemmer
#snow = SnowballStemmer('english')
def stemming(string):
    a=[snow.stem(i) for i in word_tokenize(string) ]
    return " ".join(a)

#3. LEMMATIZATION
# Initialize the lemmatizer
#wl = WordNetLemmatizer()
 
# This is a helper function to map NTLK position tags
# Full list is available here: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# Tokenize the sentence
def lemmatizer(string):
    word_pos_tags = nltk.pos_tag(word_tokenize(string)) # Get position tags
    a=[wl.lemmatize(tag[0], get_wordnet_pos(tag[1])) for idx, tag in enumerate(word_pos_tags)] # Map the position tag and lemmatize the word/token
    return " ".join(a)

def finalpreprocess(string):
    string = str(string)
    return lemmatizer(stopword(preprocess(string)))
#    return lemmatizer(preprocess(string))

# %%
#for converting sentence to vectors/numbers from word vectors result by Word2Vec
class MeanEmbeddingVectorizer(object):
    def __init__(self, word2vec):
        self.word2vec = word2vec
        # if a text is empty we should return a vector of zeros
        # with the same dimensionality as all the other vectors
        self.dim = len(next(iter(word2vec.values())))

    def fit(self, X, y):
        return self

    def transform(self, X):
        return np.array([
            np.mean([self.word2vec[w] for w in words if w in self.word2vec]
                    or [np.zeros(self.dim)], axis=0)
            for words in X
        ])

# %% [markdown]
# The precision is the ratio tp / (tp + fp) where tp is the number of true positives and fp the number of false positives. The precision is intuitively the ability of the classifier not to label as positive a sample that is negative.
#
# The recall is the ratio tp / (tp + fn) where tp is the number of true positives and fn the number of false negatives. The recall is intuitively the ability of the classifier to find all the positive samples.
#
# The F-beta score can be interpreted as a weighted harmonic mean of the precision and recall, where an F-beta score reaches its best value at 1 and worst score at 0.The F-beta score weights recall more than precision by a factor of beta. beta == 1.0 means recall and precision are equally important.
#
# The support is the number of occurrences of each class in y_true.
#
# If pos_label is None and in binary classification, this function returns the average precision, recall and F-measure if average is one of 'micro', 'macro', 'weighted' or 'samples'.
#
# Read more in the [User Guide](https://scikit-learn.org/stable/modules/model_evaluation.html#precision-recall-f-measure-metrics).

# %%
def logistic_regression_tfidf(df_train, df_test, ID, TEXT, TARGET, perc_cutoff = 80):
    if perc_cutoff > 1: perc_cutoff = perc_cutoff/100
    df_train = df_train.loc[df_train[TARGET].notnull(), [ID, TEXT, TARGET ]]
    df_train['word_count'] = df_train[TEXT].apply(lambda x: len(str(x).split()))
    #print(df_train[df_train[TARGET]==1]['word_count'].mean()) #Positive match
    #print(df_train[df_train[TARGET]==0]['word_count'].mean()) #Not positive match 
    df_train['clean_text'] = df_train[TEXT].apply(lambda x: finalpreprocess(x))
    # create Word2vec model
    #  here words_f should be a list containing words from each document. say 1st row of the list is words from the 1st document/sentence
    #  length of words_f is number of documents/sentences in your dataset
    df_train['clean_text_tok']=[nltk.word_tokenize(i) for i in df_train['clean_text']] #convert preprocessed sentence to tokenized sentence
    model = Word2Vec(df_train['clean_text_tok'],min_count=1)  #min_count=1 means word should be present at least across all documents,
    #if min_count=2 means if the word is present less than 2 times across all the documents then we shouldn't consider it
    w2v = dict(zip(model.wv.index_to_key, model.wv.vectors))  #combination of word and its vector

    #SPLITTING THE TRAINING DATASET INTO TRAINING AND VALIDATION
    # Input: "reviewText", "rating" and "time"
    # Target: "log_votes"
    X_train, X_val, y_train, y_val = train_test_split(df_train["clean_text"],
                                                      df_train[TARGET],
                                                      test_size=0.2,
                                                      shuffle=True)
    X_train_tok= [nltk.word_tokenize(i) for i in X_train]  #for word2vec
    X_val_tok= [nltk.word_tokenize(i) for i in X_val]      #for word2vec
    #TF-IDF
    # Convert x_train to vector since model can only run on numbers and not words- Fit and transform
    tfidf_vectorizer = TfidfVectorizer(use_idf=True)
    X_train_vectors_tfidf = tfidf_vectorizer.fit_transform(X_train) #tfidf runs on non-tokenized sentences unlike word2vec
    # Only transform x_test (not fit and transform)
    X_val_vectors_tfidf = tfidf_vectorizer.transform(X_val) #Don't fit() your TfidfVectorizer to your test data: it will 
    #change the word-indexes & weights to match test data. Rather, fit on the training data, then use the same train-data-
    #fit model on the test data, to reflect the fact you're analyzing the test data only based on what was learned without 
    #it, and the have compatible

    ######################################################################
    
    #FITTING THE CLASSIFICATION MODEL using Logistic Regression(tf-idf)
    lr_tfidf=LogisticRegression(solver = 'liblinear', C=10, penalty = 'l2')
    lr_tfidf.fit(X_train_vectors_tfidf, y_train)  #model

    #Predict y value for test dataset
    y_predict = lr_tfidf.predict(X_val_vectors_tfidf)
    y_prob = lr_tfidf.predict_proba(X_val_vectors_tfidf)[:,1]


    print(classification_report(y_val,y_predict))
    print('Confusion Matrix:',confusion_matrix(y_val, y_predict))

    fpr, tpr, thresholds = roc_curve(y_val, y_prob)
    roc_auc = auc(fpr, tpr)
    print('AUC:', roc_auc)

    ### EXAMINE TEST SET WITH MODEL. This includes the data from training (both pos and neg targets) ###
    df_test['clean_text'] = vd[TEXT].apply(lambda x: finalpreprocess(x)) #preprocess the data
    X_test=df_test['clean_text'] 
    X_vector=tfidf_vectorizer.transform(X_test) #converting X_test to vector
    y_predict = lr_tfidf.predict(X_vector)      #use the trained model on X_vector
    y_prob = lr_tfidf.predict_proba(X_vector)[:,1]
    df_test['predict_prob']= y_prob
    df_test['target']= y_predict
    # display(df_test[['VAERS_ID','SYMPTOM_TEXT','predict_prob','target']].head())
    # #final=df_test[['id','target']].reset_index(drop=True)
    # #final.to_csv('submission.csv')
    df_results = df_test[(
                            (df_test["target"] == 1) & 
                            (df_test["predict_prob"] >= perc_cutoff)
    )]
    num_found = df_results.shape[0]
    num_total = df_test.shape[0]
    print("{}/{} ({})".format(num_found, num_total, num_found/num_total))
    return num_found,df_results

# %%
def run_analysis(df, ID, TEXT, TARGET, iterations = 10):
    results = []
    for i in range(0,iterations,1):
        print(); print(" Iteration {} {} ==========".format(i, TEXT))
        df_train = df.loc[vd[TARGET].notnull(), [ID,TEXT,TARGET]]
        df_train['word_count'] = df_train[TEXT].apply(lambda x: len(str(x).split()))
        print("Average word count, positive targets: {}".format(df_train[df_train[TARGET]==1]['word_count'].mean())) #Has covid
        print("Average word count, negative targets: {}".format(df_train[df_train[TARGET]==0]['word_count'].mean())) #Has covid
        num_found,df_results = logistic_regression_tfidf(df_train, df, ID,TEXT,TARGET)
        results.append((df_results, num_found, num_found/df.shape[0]))

    for i in results:
        print(i[1], i[2])
    
    return results

# %%
def parse_out_meds(df):
    def parse_meds_from_phrase(phrase): # Takes an iterable of strings
        # Parse out the vitamins first, since they con be single or multiple words
        p1 = "([multi]*vit[amins]*\s*[abcdek]{1}\d?( |$))" # I.e. "vitamin c" or "multivitamin d3", "vitamins b", etc.
        p2 = "(([multi]*vit[amins]*\s*)?thiamin|riboflavin|niacin|(pantothenic\s*acid)|pyridoxal|cobalamin|biotin|folate|(folic\s*acid))" # I.e. "vitamin(s) thiamin"
        p3 = "([multi]*vit[amins]*( |$))" # "<multi>vitamin<s>" only
        p = '|'.join([p1, p2, p3])

        m = re.findall(p, phrase, re.IGNORECASE)
        # Remove any contiguous strings of quotes, brackets, or parens. Leave commas and spaces
        m = re.sub("[\'\"\]\[\(\)]*", "", str(m)) 
        # Split by commas, and remove words  that are all spaces. Leaves spaces between words
        m = [w.strip() for w in m.split(",") if not re.match("^\s*$", w) ] 
        meds_list = list(set(m)) # remove duplicate strings

        # Remove all the found vitamins from phrase
        for vit in m:
            phrase = phrase.replace(vit, "")

        # Turn remaining meds into set
        phrase = " ".join(phrase.split()) # remove blocks of contiguous whitespaces
        phrase = list(set(phrase.split(" "))) # Set to remove dups, then back to a list for adding

        # Add together
        meds_list += phrase

        return sorted(meds_list, key=str.lower)
        
    s = df["OTHER_MEDS"].apply(lambda x: preprocess(str(x)))
    s = s.apply(stopword_medications)
    for phrase in s: 
        result = parse_meds_from_phrase(phrase)
        print(result)

parse_out_meds(vd)
# Out:
# ['alphagan', 'chlorthlidone', 'chondrotin', 'colocrys', 'gabapentin', 'glusosamine', 'lanaoprost', 'lantus', 'lisinopril', 'metoprol', 'needed', 'novolog', 'solostar', 'tartrate']
# ['fentanyl', 'hydrocodone', 'mertazipine', 'quietapine']
# ['amitizide', 'carbidoba', 'chloride', 'clonazepam', 'ellipta', 'escalitapram', 'fentanyl', 'incruse', 'levodopa', 'levothyroxine', 'mirtazipane', 'morphine', 'potassium', 'prednisone', 'sulfate', 'torsemide', 'trazadone']
# ['benaprezil', 'chloride', 'glipizide', 'latanoprost', 'levothyroxine', 'metformin', 'metoprolol', 'potassium', 'pravastatin', 'tartrate']
# ['bid', 'capsule', 'cogentin', 'dyazide', 'hctz', 'invega', 'lipitor', 'lithium', 'months', 'norvasc', 'oxybutynin', 'q', 'qd', 'qhs', 'qid', 'trenza', 'triamterene']
# ['acid', 'albuteral', 'amlodipine', 'carvedilol', 'chloride', 'ipratropium', 'levetiracetam', 'olanzapine', 'sodium', 'sulfate', 'symbicort', 'valproic']
# ['acid', 'albuterol', 'asa', 'benadryl', 'colace', 'ferrous', 'folic acid', 'gabapentin', 'glycol', 'ipratropium', 'melatonin', 'mucomyst', 'mvi', 'oxycodone', 'periactin', 'polyethylene', 'rosuvastatin', 'sennosides', 'seroquel', 'sulfate', 'valproic', 'venlafaxine', 'vitamin c']
# ['amlodipine', 'asa', 'atrovastatin', 'donepezil', 'flomax', 'lisinopril', 'loratadine', 'metoprolol', 'pentoxifylline', 'plavix', 'tartrate', 'trazodone']
# ['determined']
# ['nan']
# ['acetaminophen', 'amlodipine', 'besylate', 'capsaicin', 'chest', 'cong', 'cough', 'cream', 'dextromethorphan', 'dm', 'extra', 'guaifenesin', 'leflunomide', 'levothy', 'liquid', 'morphine', 'robitussin', 'solu', 'strength', 'tab', 'tablet', 'tylenol']
# ['nan']
# ['cetirizine', 'lactaid']
# ['acetaminophen', 'atenolol', 'colace', 'lisinopril', 'mirtazapine', 'omeprazole', 'simvastatin', 'vitamin']
# ['areds', 'capsule', 'chloride', 'er', 'ferrex', 'folic acid', 'furosemide', 'isosorbide', 'lactulose', 'meq', 'metoprolol', 'mononoitrate', 'omeprazole', 'one', 'potassium', 'preservision', 'ranolazine', 'sucralf']
# ['unknown']
# ['nan']
# ['nan']
# ['bid', 'furosemide', 'olanzapine', 'qd', 'units', 'vitamin']
# ['acetaminophen', 'active', 'amlodipine', 'besylate', 'day', 'elevated', 'essential', 'every', 'give', 'hours', 'hyp', 'mouth', 'needed', 'one', 'pain', 'phone', 'primary', 'related', 'tablet', 'temp', 'time']
# ['fluticasone', 'hcl', 'lasix', 'omeprazole', 'ropinrole', 'sucarafate']
# ['nan']
# ['nan']
# ['ativan', 'glycol', 'morphine', 'olanzapine', 'polyethylene', 'senna']
# ['nan']
# ['unknown']
# ['albuterol', 'azelastine', 'calcium', 'eliquis', 'eye', 'gtts', 'lasix', 'lopressor', 'magnesium', 'omeprazole', 'oxide', 'pepcid', 'potassium', 'prozac', 'singulair', 'terazosin']
# ['aldactone', 'aspirin', 'lasix', 'potassium', 'spiriva', 'tylenol']
# ['acetaminophen', 'celebrex', 'docusate', 'famotidine', 'glycol', 'lexapro', 'namenda', 'polyethylene', 'seroquel', 'simvastatin', 'sodium', 'tamsulosin', 'trazodone']
# ['nan']
# ['amlodipine', 'aspirin', 'besylate', 'cap', 'carbamazepine', 'docusate', 'dr', 'er', 'metoprolol', 'multivitamin', 'olmesa', 'omeprazole', 'po', 'succ', 'tab', 'tid']
# ['nan']
# ['aspirin', 'avorstatin', 'oxycodone']
# ['ca', 'day', 'every', 'friday', 'gabapentin', 'hours', 'monday', 'needed', 'norco', 'orally', 'sabcubitril', 'tablet', 'tablets', 'torsemide', 'valsartan', 'warfarin']
# ['nan']
# ['acetaminophen', 'chloride', 'encephalopathy', 'enulose', 'er', 'extended', 'hydrocodone', 'hydroxide', 'lactulose', 'magnesia', 'magnesium', 'milk', 'potassium', 'release', 'solution', 'suspension', 'tablet']
# ['carbodopa', 'levodopa', 'lorazepam', 'metoprolol', 'miralax', 'mirtazipine', 'pantoprazole', 'plus', 'quetiapine', 'senna']
# ['advair', 'alprazolam', 'amlodipine', 'asa', 'cilostazol', 'lamotrigine', 'losartan', 'metoprolol', 'omprazole', 'simvastatin']
# ['unknown']
# ['nan']
# ['unknown']
# ['areds', 'bisulfate', 'campor', 'clopidogrel', 'ferrous', 'fluticasone', 'gluconate', 'lisinopril', 'met', 'methol', 'metoprolol', 'miralax', 'mom', 'nitroglycerin', 'ondansetron', 'preservision', 'prn', 'propionate', 'spironolactone', 'sublingual', 'succinate', 'suspension', 'tramadol', 'vit']
# ['nan']
# ['acetaminophen', 'carbidopa', 'citalopram', 'donepezil', 'er', 'eucerin', 'finasteride', 'flomax', 'fumarate', 'hbr', 'hcl', 'latanoprost', 'lax', 'levodopa', 'omeprazole', 'quetiapine', 'senna']
# ['amiodarone', 'carvedilol', 'cont', 'eliquis', 'ferrous', 'hcl', 'sulfate']
# ['nan']
# ['none']
# ['confirmed', 'hydrochlorthiazide', 'record']
# ['amlodipine', 'bid', 'bisoprolol', 'dexamethasone', 'dinitrate', 'failure', 'furosemide', 'isosorbide', 'itching', 'levothyroxine', 'nasal', 'po', 'related', 'renal', 'saline', 'spray', 'tid', 'tylenol']
# ['unknown']
# ['aspirin', 'atenolol', 'caps', 'centrum', 'citrical', 'coded', 'colon', 'enteric', 'health', 'levothyroxin', 'lisinipril', 'phillips', 'silver', 'vitamin']
# ['nan']
# ['calcium', 'cholecalciferol', 'fish', 'melatonin', 'oil', 'tablet', 'tylenol']
# ['nan']
# ['nan']
# ['medications', 'patient', 'refusing', 'take', 'year']
# ['none']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['unknown']
# ['cranberry', 'e', 'immodium', 'linzess', 'lipitor', 'melatonin', 'metformin', 'neurotin', 'percocet', 'plavix', 'proair', 'protonix', 'prozac', 'ropinirole', 'symbicort', 'synthroid', 'thiamin', 'tylenol', 'vit c', 'voltaren', 'zanax', 'zofran']
# ['amlodipine', 'aspirin', 'atorvastatin', 'listed', 'medications', 'office', 'patient', 'still', 'taking', 'time', 'unknown', 'vaccination', 'xarelto']
# ['unknown']
# ['nan']
# ['atorvastin', 'metform']
# ['aspirin', 'diazepam', 'doxepin', 'duloxetine', 'hcl', 'juven', 'lamotri', 'levothyroxin', 'loratadine', 'melatonin', 'mucus', 'olanzapine', 'pow', 'prazosin', 'pregabalin', 'relief']
# ['none']
# ['benztropine', 'bid', 'cetirizine', 'current', 'date', 'group', 'home', 'medications', 'midodrine', 'patient', 'prn', 'proamatine', 'resident', 'start', 'tab', 'tid', 'treatments']
# ['calcium', 'lisinopril', 'mucinex', 'mvi', 'namenda', 'tramadol', 'tylenol']
# ['nan']
# ['husband', 'knew', 'medications', 'several', 'took']
# ['amiodarone', 'anxiety', 'apap', 'ativan', 'bid', 'claritin', 'coumadin', 'fri', 'gabapentin', 'miralax', 'mon', 'pain', 'phantom', 'po', 'prn', 'sat', 'sun', 'temp', 'thurs', 'tues']
# ['bumetanide', 'con', 'cream', 'eliquis', 'fosamax', 'klor', 'lisinopril', 'meloxicam', 'oxybutynin', 'prednisone', 'promethazine', 'singulair', 'triamcinolone']
# ['nan']
# ['']
# ['allopurinol', 'amitriptyline', 'amlodipine', 'asa', 'baclofen', 'candesartan', 'chloride', 'con', 'gabapentin', 'hydyralazine', 'insulin', 'klor', 'lasix', 'lipitor', 'lispro', 'meq', 'oxybutynin', 'turmeric', 'tylenol', 'vit']
# ['nan']
# ['act', 'day', 'dilitiazem', 'eliquis', 'er', 'every', 'furosemide', 'hfa', 'hours', 'inhaler', 'kcl', 'losartan', 'mcg', 'meq', 'needed', 'po', 'puffs', 'ranitidine', 'symbicort', 'ventolin']
# ['unknown']
# ['idk']
# ['nan']
# ['atorvastatin', 'levothyroxine', 'metamucil', 'metformin', 'multivitamin', 'senna']
# ['nan']
# ['continuation', 'field', 'see']
# ['fentanyl', 'mirtazapine', 'patch']
# ['brimonidine', 'cephalexin', 'donepezil', 'latanoprost', 'losartan', 'metoprolol', 'timolol']
# ['acetamenaphin', 'cefritriaxone', 'citalopram', 'hydrocodone', 'lidocaine']
# ['nan']
# ['nan']
# ['unknown']
# ['unknown']
# ['nan']
# ['nan']
# ['', 'multivitamin', 'vitamin']
# ['nan']
# ['unknown']
# ['nan']
# ['nan']
# ['nan']
# ['attached', 'see']
# ['nan']
# ['lorazepam', 'solution']
# ['amlodipine', 'asa', 'atorvastatin', 'baclofen', 'levothyr', 'risperidone']
# ['abilify', 'albuterol', 'alexandrina', 'cranberry', 'effexor', 'furosemide', 'glycol', 'ipratropium', 'lasix', 'leaf', 'polyethylene', 'senna', 'tylenol']
# ['nan']
# ['balance', 'colace', 'diltiazem', 'er', 'escitalopram', 'magnesia', 'metformin', 'milk', 'oxalate', 'refresh', 'systane', 'tears']
# ['aspirin', 'lasix', 'levothyroxine', 'mcg', 'senna', 'tylenol']
# ['amitiza', 'anastrozole', 'calcium', 'carbonate', 'docusate', 'fiber', 'fle', 'fluvoxamine', 'gavilax', 'glucerna', 'ketoconazole', 'lax', 'levemir', 'levetiracetam', 'loratadine', 'lotion', 'maleate', 'medications', 'needed', 'novolog', 'prolia', 'selenium', 'sulfide', 'vimpat', 'vitamin']
# ['depakene', 'haldol']
# ['unknown']
# ['cobalamin', 'colchicine', 'cyano', 'fluoxetine', 'levothyroxine', 'risperidone', 'torsemide', 'tramadol']
# ['acid', 'ativen', 'butrans', 'citrate', 'citric', 'patch', 'potassium', 'tylenol']
# ['nan']
# ['enfamil', 'formula', 'gentlease']
# ['alendronate', 'artificial', 'asa', 'atorvastatin', 'cal', 'claritin', 'codeine', 'estradiol', 'gabapentin', 'latuda', 'mag', 'melatonin', 'mom', 'multi', 'sertraline', 'tears', 'tylenol', 'vit', 'zinc']
# ['carvedilol', 'levothyroxine', 'losartan']
# ['none', 'reported', 'unknown']
# ['none']
# ['nan']
# ['alvesco', 'amiodarone', 'atrovent', 'bactrim', 'carafate', 'coreg', 'cymbalta', 'flomax', 'guaifenesin', 'keppra', 'levothroid', 'lipitor', 'megace', 'potassium', 'prednisone', 'protonix', 'rifampin']
# ['nan']
# ['diazepam', 'levothyroxine', 'magnesium', 'olanzapine', 'omeprazole', 'oxide', 'sertraline', 'vitamin']
# ['keppra', 'levothyroxine', 'lorazepam', 'miralax', 'olanzapine', 'risperidone', 'trazadone']
# ['carvedilol', 'losartan', 'spironolactone']
# ['atorvastatin', 'bid', 'biotin', 'calcium', 'drop', 'eye', 'ezetimibe', 'fish', 'gabapentin', 'hr', 'lysine', 'mag', 'metoprolol', 'oil', 'prilosec', 'q', 'qhs', 'ranola', 'restasis', 'tab', 'tart', 'zinc']
# ['amlodipine', 'cholecalciferol', 'finasteride', 'furosemide', 'metoprolol', 'tamsulosin', 'tartrate']
# ['contact', 'facility', 'medications', 'needing', 'nursing', 'please', 'resident', 'skilled']
# ['unk']
# ['depakote', 'lexapro', 'lisinopril', 'multiple', 'senna', 'seroquel', 'tylenol', 'vitamin']
# ['unk']
# ['aspirin', 'brillinta', 'chloride', 'clonzepam', 'colace', 'donepezil', 'effexor', 'er', 'ferrous', 'flomax', 'metformin', 'metoprolol', 'n', 'namenda', 'oxybutynin', 'percocent', 'potassium', 'protonix', 'senna', 'succinate', 'sucralfate', 'sulfate', 'ultram', 'vitamin b', 'xr']
# ['ace', 'acetaminophen', 'acetate', 'amitriptyline', 'atorvastatin', 'coenzyme', 'eliquis', 'er', 'flecainide', 'furosemide', 'lisinpril', 'metoprolol', 'mucinex', 'norco', 'pepcid', 'q', 'succinate', 'synthroid', 'verapamil', 'vit']
# ['motrin', 'tylenol', 'vitamin c']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['capsule', 'clozapine', 'clozaril', 'ergocalciferol', 'hcl', 'mcg', 'miralax', 'multivitamin', 'powder', 'qd', 'remeron', 'sertraline', 'simvastatin', 'synthroid', 'tablet', 'tricor', 'ut']
# ['alvesco', 'cellcept', 'coreg', 'inh', 'mepron', 'miralax', 'paxil', 'prednisone', 'prilosec', 'susp', 'trazodone', 'tricor', 'umeclidinum', 'xopenex', 'zetia', 'zyprexa']
# ['nan']
# ['allopurinol', 'atorvastatin', 'finasteride', 'fluoxetine', 'furosemide', 'hydralazine', 'metformin', 'nadolol', 'omeprazole', 'ramipril', 'tamsulosin']
# ['acetaminophen', 'aspirin', 'cr', 'digoxin', 'diltiazem', 'namenda', 'toprol', 'vitamin', 'xl', 'zyrtec']
# ['nan']
# ['bid', 'depakote', 'hs', 'hydrochlorothiazide', 'metoprolol', 'po', 'q', 'terazosin']
# ['nan']
# ['acid', 'acidophilus', 'alpha', 'aspirin', 'bumetanide', 'c', 'calcium', 'citrate', 'coconut', 'curcumin', 'dur', 'ec', 'escitalopram', 'flomax', 'gel', 'k', 'krill', 'levothyroxine', 'lioresal', 'lipoic', 'magox', 'mantoux', 'oil', 'preservis', 'proamatine', 'proscar', 'vitamin', 'vitamin b']
# ['doxycycline', 'er', 'levothyroxine', 'loperamide', 'metoprolol', 'multivitamin', 'nitroglycerin', 'pepcid', 'simethicone', 'succinate', 'tylenol', 'ultram', 'xanax', 'zinc']
# ['albuterol', 'anora', 'bumex', 'carvediol', 'flovent', 'omeprazole']
# ['nan']
# ['unknown']
# ['unknown']
# ['amlopidine', 'atorvastin', 'besylate', 'bid', 'calcium', 'carbidopa', 'hcl', 'levodopa', 'melatonin', 'metformin', 'multiple', 'patch', 'po', 'qd', 'qhs', 'rivastigmine', 'senna', 'tid', 'vitamin']
# ['acid', 'ascorbic', 'bid', 'famotidine', 'glycol', 'gt', 'hcl', 'kit', 'liquid', 'memantine', 'minerals', 'multi', 'multiple', 'polyethylene', 'qd', 'senna', 'sennosides', 'tablet', 'tablets', 'vitamins', 'vite']
# ['cranberry', 'pills', 'senna']
# ['lidocaine', 'patch', 'topical', 'xarelto']
# ['nan']
# ['nan']
# ['acetaminophen', 'acyclovir', 'aleve', 'amlodipine', 'aspirin', 'atenolol', 'cefpodoxime', 'chlorthalidone', 'dexamethasone', 'fluconazole', 'levetiracetam', 'lisinopril', 'minerals', 'multivitamin', 'potassium', 'probiotic', 'topiramate']
# ['unknown']
# ['albuterol', 'aspirin', 'crestor', 'furosemide', 'gel', 'hydrochlorothiazide', 'inhaler', 'levothyroxine', 'nitroglycerin', 'prasugrel', 'sildenafil', 'singulair', 'sl', 'spironolactone', 'testosterone', 'toprol', 'vit', 'xl']
# ['ask', 'home', 'nursing']
# ['nan']
# ['nan']
# ['nan']
# ['allopurinol', 'amlodipine', 'insulin', 'levemir', 'levothryoxine', 'lispro', 'mcg', 'nightly', 'norvasc', 'per', 'scale', 'simvastatin', 'synthroid', 'u', 'unit', 'units', 'ups', 'us', 'zyoprim']
# ['furosemide', 'metoprolol', 'tartrate']
# ['aspirin', 'baby', 'claritin', 'co', 'crestor', 'drops', 'eye', 'fish', 'gel', 'germ', 'hits', 'hour', 'oil', 'prime', 'q', 'replatha', 'testosterone', 'valsart', 'weirder', 'wheat', 'zaria']
# ['acetaminophen', 'atorvastatin', 'calcium', 'diclofenac', 'eliquis', 'gel', 'hcl', 'iron', 'mcg', 'melatonin', 'metformin', 'multivital', 'nifedipine', 'sodium', 'tablet', 'vitamin']
# ['nan']
# ['listed', 'none']
# ['amoxicillin']
# ['amlodipine', 'dicyclomine', 'ezetimibe', 'levothyroxine', 'omeprazole', 'triamcinolone']
# ['daughter', 'know', 'list', 'medications', 'reporting', 'time']
# ['nan']
# ['nan']
# ['benefiber', 'carbidopa', 'er', 'finasteride', 'lactobacillus', 'lasix', 'levodopa', 'maleate', 'metoprolol', 'multivitamin', 'oxubytynin', 'pravastatin', 'succinate', 'tabs', 'tamsulosin', 'timolol', 'vite']
# ['unknown']
# ['nan']
# ['atorvastatin', 'ibuprofen', 'morphine', 'oxybutinin', 'sulfate']
# ['nan']
# ['facility', 'provided']
# ['medications', 'needed', 'scheduled', 'tylenol', 'zyrtec']
# ['acetaminophen', 'antacid', 'antifungal', 'atenolol', 'bisacodyl', 'calcium', 'chloride', 'citrate', 'complete', 'cream', 'creon', 'donepezil', 'estradiol', 'famotidine', 'ferrous', 'ibandronate', 'lexapro', 'memantine', 'pearls', 'potassium', 'probiotic', 'seroquel', 'simvastatin', 'sulfate']
# ['famotidine', 'finasteride', 'folic acid', 'mcg', 'qd', 'senna']
# ['nan']
# ['nan']
# ['aspirin', 'ativan', 'coreg', 'cymbalta', 'e', 'folic acid', 'multivitamin', 'norvasc', 'prostat', 'thiamin', 'time', 'vitamin c']
# ['apixaban', 'cont', 'diltiazem', 'levothyroxine', 'page', 'prednisone']
# ['breo', 'calcium', 'colace', 'con', 'coreg', 'ellipta', 'klor', 'lactulose', 'miralax', 'multi', 'nystatin', 'pantoprazole', 'simethicone', 'torsemide', 'trazodone', 'vit b', 'vitamin', 'vitamin c']
# ['unknown']
# ['amlodipine', 'aricept', 'bactrim', 'namenda', 'remeron']
# ['aspirin', 'atorvastatin', 'bumetanide', 'carvedilol', 'keppra', 'lisinopril', 'miralax', 'mirtazapine', 'pantoprazole', 'senna', 'tamsulosin', 'tylenol', 'vit']
# ['acetaminophen', 'alogliptin', 'atorvastatin', 'benzoate', 'bisacodyl', 'calcium', 'ceftriaxone', 'chloride', 'enema', 'er', 'exter', 'gabapentin', 'hcl', 'lantus', 'levothyroxine', 'magnesia', 'milk', 'potassium', 'rectal', 'santyl', 'sodium', 'solostar', 'suppository', 'tramadol']
# ['acetate', 'albuterol', 'aspirin', 'atorvastatin', 'buspirone', 'calcium', 'clonidine', 'ergocalciferol', 'hydralazine', 'hydroxyzine', 'levothyroxine', 'metoprolol', 'mutlivitamins', 'ondansetron', 'oxycodone', 'pantoprazole', 'rifaximin', 'ropinirole']
# ['nan']
# ['nan']
# ['alfuzosin', 'allopurinol', 'amlodipine', 'aspirin', 'finasteride', 'lexapro', 'mirtazipine', 'multi', 'multivitamin', 'ropinirole', 'sinemet', 'trospium', 'vitamin']
# ['amiodarone', 'fergon', 'ferrous', 'furosemide', 'gluconate', 'iron', 'lasix', 'lidocaine', 'melatonin', 'mycostatin', 'nystatin', 'pacerone', 'solution', 'suspension', 'tablet', 'unit', 'xylocaine']
# ['nan']
# ['nan']
# ['amlodipine', 'lipitor', 'lisinopril']
# ['carvedilol', 'docusate', 'eliquis', 'losartan', 'metolazone', 'torsemide']
# ['nan']
# ['allopurinol', 'atorvastatin', 'bid', 'bumetanide', 'bupropn', 'carvedilol', 'cinacalcet', 'eplerenone', 'fluoxetine', 'hs', 'mirtazapine', 'pan', 'tabs', 'tylenol']
# ['unavail']
# ['cholecalciferol', 'duloxetine', 'fenofibrate', 'gabapentin', 'hydrocortisone', 'melatonin', 'metformin', 'metoprolol', 'mineral', 'nitroglycerin', 'oil', 'omeprazole', 'pravastatin', 'quetiapine', 'selenium', 'shampoo', 'succinate', 'sulfide', 'sumatriptan', 'suppository']
# ['atovastatin', 'ferrous', 'finasteride', 'flomax', 'humulin', 'n', 'pantoprazole', 'proair', 'reglan', 'spiriva', 'sulfate', 'turmeric']
# ['nan']
# ['acetaminophen', 'betapace', 'c', 'capsule', 'carbonate', 'delayed', 'e', 'extra', 'f', 'fluticasone', 'glycol', 'miralax', 'omeprazole', 'po', 'polyethylene', 'prilosec', 'propionate', 'release', 'renvela', 'sevelamer', 'sotalol', 'strength', 'tablet', 'tylenol']
# ['area', 'cartia', 'day', 'drop', 'er', 'erythromycin', 'eye', 'ferrou', 'folic acid', 'hydroxychloroquine', 'lasix', 'metoprolol', 'succinate', 'sulfate', 'tabs', 'xt', 'zaditor']
# ['nan']
# ['active', 'amlodipine', 'aspirin', 'besylate', 'bid', 'carvedilol', 'chewable', 'cholecalciferol', 'mcg', 'otc', 'po', 'qdaily', 'qpm', 'tab', 'vit']
# ['aspirin', 'atorvastatin', 'ec', 'evening', 'half', 'lipitor', 'mouth', 'olanzapine', 'one', 'pm', 'tablet', 'take', 'zyprexa']
# ['albuterol', 'antibiotic', 'inhaler', 'metoprolol', 'nebulizer', 'per', 'saline', 'vespi', 'week']
# ['divalproex', 'dr', 'drops', 'fumarate', 'latanoprost', 'lexapro', 'quetiapine', 'senna', 'sodium', 'tab']
# ['asa', 'benztropine', 'buspar', 'depakote', 'er', 'gabapentin', 'imodium', 'lasix', 'melatonin', 'multi', 'omeprazole', 'potassium', 'resperidone', 'sertraline', 'vit', 'vitamin e', 'zofran']
# ['aspirin', 'b', 'biotin', 'levothyroxine', 'melatonin', 'namenda', 'trazodone', 'vit', 'xanax', 'zyprexa']
# ['simvastatin']
# ['acetaminophe', 'amlodipine', 'dispersible', 'every', 'hours', 'kenalog', 'line', 'mouth', 'nausea', 'needed', 'norvasc', 'odt', 'ointment', 'ondansetron', 'st', 'tab', 'tablet', 'take', 'triamcinolone', 'zofran']
# ['ac', 'acid', 'ascorbic', 'cetirizine', 'eliquis', 'er', 'escitalopram', 'finasteride', 'gel', 'hcl', 'injection', 'mcg', 'metoprolol', 'oxalate', 'pantoprazole', 'sodium', 'succinate', 'tablet', 'tamsulosin', 'teriparatide', 'vitamin', 'voltaren']
# ['nan']
# ['unknown']
# ['bid', 'losartan', 'metformin', 'qd', 'simvastatin', 'tamsulosin']
# ['nan']
# ['unknown']
# ['center', 'living', 'n', 'resident']
# ['disclosed', 'none']
# ['allopurinol', 'atrovastatin', 'bisulfate', 'carospir', 'chloride', 'clopidogrel', 'dr', 'duloxetine', 'er', 'hcl', 'insulin', 'lantus', 'levothyroxine', 'lidocaine', 'mcg', 'meq', 'patch', 'potassium', 'prilosec', 'psylliu', 'suspension', 'units']
# ['unknown']
# ['unknown']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['unknown']
# ['list', 'several']
# ['acid', 'amantadine', 'amphetamine', 'cefepime', 'clobazam', 'clonazepam', 'dextroamphetamine', 'famotidine', 'gabapentin', 'glycol', 'keppra', 'lovenox', 'polyethylene', 'propanolol', 'robinul', 'senna', 'sertaline', 'valproic', 'vimpat']
# ['nan']
# ['ambien', 'wellbutrin']
# ['amiodarone', 'aspirin', 'atorvastatin', 'er', 'furosemide', 'levothyroxine', 'mcg', 'metoprolol', 'nitroglycerin', 'polyeth', 'prn', 'rivaroxaban', 'sl', 'succinate', 'tamsulosin']
# ['acid', 'asorbic', 'cholecalciferol', 'cimetadine', 'clonazepam', 'lomotrigine', 'melatonin', 'phenergan', 'quetiapine', 'vit', 'zinc']
# ['nan']
# ['acetaminophen', 'aspirin', 'celecoxib', 'docusate', 'flexpen', 'furosemide', 'glimepiride', 'injection', 'injector', 'iron', 'lantus', 'lisinopril', 'novolog', 'nu', 'pen', 'senokot', 'sodium', 'solostar', 'unit']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['unknown']
# ['nan']
# ['nan']
# ['acetaminophen', 'atropine', 'biotin', 'concentrate', 'e', 'lorazepam', 'magnesia', 'milk', 'moisturizing', 'morphine', 'mouth', 'odt', 'opthamlic', 'prn', 'solution', 'sulfate', 'suppository', 'suspension', 'tablet', 'zofran']
# ['cholestyramine', 'dicolfenac', 'divalproex', 'eliquis', 'furosemide', 'gabapentin', 'gel', 'hcl', 'hydroxyzine', 'levetiracetam', 'levothyroxine', 'sodium', 'topical', 'tramadol', 'trazodone']
# ['acetaminophen', 'alcohol', 'atropine', 'concentrate', 'fentanyl', 'hr', 'lorazepam', 'mcg', 'morphine', 'ophthalmic', 'patch', 'polyvinyl', 'solution', 'sulfate', 'suppository']
# ['nan']
# ['nan']
# ['acetaminophen', 'digoxin', 'glargine', 'insulin', 'loratadine', 'simvastatin', 'tamsulosin', 'warfarin']
# ['atorvastatin', 'enalapril', 'maleate', 'maxzide', 'metoprolol']
# ['nan']
# ['unknown']
# ['unknown']
# ['nan']
# ['allopurinol', 'calcium', 'carafate', 'carbonate', 'colace', 'famotidine', 'isosorbide', 'klonipin', 'losartan', 'metoprolol', 'myrbetriq', 'synthroid', 'tylenol', 'zoloft']
# ['colace', 'fosamax', 'januvia', 'lantus', 'levoxyl', 'lisinopril', 'metoprolol', 'simvastatin', 'trazodone', 'zocor']
# ['acetate', 'albuterol', 'aspirin', 'ativan', 'ayr', 'biotene', 'cal', 'docusate', 'dry', 'florajen', 'gabapentin', 'hcl', 'hydralazine', 'hydrocortisone', 'isosource', 'ketoconazole', 'lasix', 'li', 'lopressor', 'moisturizing', 'mouth', 'multivitamin', 'nasal', 'pl', 'saline', 'sodium', 'spray', 'vhn']
# ['acetate', 'asprin', 'calcium', 'ensure', 'eucerin', 'furosemide', 'glipizide', 'omeprazole', 'plus', 'renvela', 'rifampin', 'sensipar', 'vitamin']
# ['nan']
# ['acetaminophen', 'alexandrina', 'hydrocodone', 'plus', 'senna', 'vitamin']
# ['nan']
# ['haloperidol', 'levetiracetam', 'lorazepam', 'metoprolol', 'oxycodone', 'pantoprazole', 'quetiapine', 'senna', 'ventolin']
# ['fluticasone', 'isorbide', 'lasix', 'metoprolol', 'nitro', 'omeprazole', 'prilosec', 'senna']
# ['alendronate', 'divalproex', 'metoprolol', 'mirabegron', 'olanzapine', 'proair', 'prozac']
# ['acetaminophen', 'aspirin', 'axitinib', 'bisacodyl', 'chondroitin', 'duloxetine', 'ferrous', 'glucosamine', 'inlyta', 'lovastatin', 'magnesium', 'norco', 'senna', 'sulfate', 'tamsulosin', 'tresiba', 'warfarin']
# ['atorvastatin', 'calcium']
# ['albuterol', 'asa', 'buspar', 'depakote', 'fibercon', 'flomax', 'morniflumate', 'salbutamol', 'vit c', 'zyprexa']
# ['nan']
# ['ativan', 'levothyroxine', 'sodium']
# ['nan']
# ['nan']
# ['unknown']
# ['atorvastatin', 'calcitrol', 'calcium', 'clopidogrel', 'digoxin', 'eliquis', 'folic acid', 'latanoprost', 'levothyroxine', 'melatonin', 'methotrexate', 'metoprolol', 'pantoprazole', 'prednisone']
# ['act', 'aers', 'albuterol', 'allopurinol', 'aspirin', 'baclofen', 'bystolic', 'clobetasol', 'cobalamin', 'cream', 'cyano', 'dose', 'external', 'fish', 'hfa', 'low', 'mcg', 'oil', 'oral', 'propionate', 'sulfate', 'tablet', 'tabs']
# ['nan']
# ['known']
# ['unknown']
# ['acetaminophen', 'albuterol', 'day', 'days', 'every', 'hrs', 'lisinopril', 'per', 'prilosec', 'probiotic', 'prozac', 'puffs', 'spray', 'symbicort', 'veramyst', 'vitamin b', 'x']
# ['furosemide', 'gabapentina', 'levothyroxine', 'losartan', 'pravastatin']
# ['unknown']
# ['covid', 'facility', 'negative', 'outbreak', 'tested', 'two', 'week']
# ['nan']
# ['nan']
# ['nan']
# ['atravastatin', 'bupropion', 'ketoconazole', 'lisinoprol', 'sertraline', 'xarelto']
# ['amlodipine', 'atorvastatin', 'benzoate', 'calcium', 'losartan', 'metformin', 'metoprolol', 'potassium', 'succinate']
# ['filing', 'information', 'making', 'son', 'time']
# ['unknown']
# ['bisoprolol', 'fluticasone', 'montelukast', 'oxybutynin']
# ['captopril', 'cl', 'er', 'furosemide', 'gabapentin', 'hydralazine', 'indomethacin', 'meg', 'metoprolol', 'micro', 'oxybutynin', 'pot', 'spironolactone', 'tab', 'tamsulosin', 'tart', 'venlafaxine', 'verapamil']
# ['unknown']
# ['nan']
# ['areds', 'doxazosin', 'eye', 'losartan', 'metoprolol', 'vitamins']
# ['nan']
# ['nan']
# ['aspirin', 'atorvastatin', 'c', 'cilostazol', 'e', 'glimepiride', 'lisinopril', 'metformin', 'methimazole', 'propranolol']
# ['nan']
# ['acetonide', 'citrate', 'creon', 'doxycycline', 'eliquis', 'furosemide', 'hcl', 'hyciate', 'k', 'losartan', 'pantoprazole', 'potassium', 'sildenafil', 'sodium', 'stendra', 'tadalafil', 'tramadol', 'trazodone', 'triamcinolone']
# ['nan']
# ['nan']
# ['nan']
# ['acid', 'adult', 'ascorbic', 'carbonate', 'carvedilol', 'e', 'lisinopril', 'minerals', 'multiple', 'multivitamin', 'sevelamer', 'tab', 'tablet', 'thiamin', 'vitamins']
# ['nan']
# ['unknown']
# ['caps']
# ['coumadin', 'inhaler', 'lasix', 'mirtazapine', 'mvi', 'protonix', 'ursodial', 'ventolin']
# ['nan']
# ['atorvastatin', 'avodart', 'calcium', 'capsule', 'colace', 'counter', 'finasteride', 'fish', 'nabumetone', 'oil', 'omiprazole', 'plus', 'tamsulosin']
# ['nan']
# ['nan']
# ['aleve', 'aspirin', 'bisacodyl', 'calcium', 'carb', 'cholecalciferol', 'cream', 'diclofenac', 'fluticasone', 'hycacyamine', 'hydromorphone', 'inhaler', 'ketoconazole', 'levemir', 'lidocaine', 'lisinopril', 'mematine', 'methcarbamol', 'metoprolol', 'patch', 'salmeterol', 'sulfate', 'tylenol']
# ['acetaminophen', 'aspirin', 'atorvastatin', 'bicalutamide', 'lisinopril', 'metoprolol', 'multivitamin', 'oxycodone', 'plavix', 'seroquel', 'sertraline', 'vanicream']
# ['known']
# ['nan']
# ['diabetes', 'prescription']
# ['aspirin', 'atenolol', 'atorvastatin', 'buspirone', 'chondroitin', 'depakote', 'er', 'glucosamine', 'mirabegron', 'miralax', 'mvm', 'ocuviteeye', 'pantoprzole', 'potassium', 'zyprexa']
# ['ativan', 'colace', 'dicyclomine', 'every', 'hours', 'mcg', 'med', 'metoprolol', 'neurontin', 'norco', 'pass', 'synthroid', 'tartrate']
# ['listed', 'none']
# ['nan']
# ['nan']
# ['nan']
# ['acetaminophen', 'aspirin', 'atorvastatin', 'capsaicin', 'days', 'ec', 'glipizide', 'glucose', 'latanoprost', 'lisinopril', 'metoprolol', 'naloxone', 'naproxen', 'nasal', 'paliperidone', 'q', 'sertraline', 'sp', 'tartrate']
# ['know', 'time']
# ['amlodipine', 'aspirin', 'capsule', 'cholecalciferol', 'e', 'eliquis', 'hcl', 'inrebic', 'ondansetron', 'oral', 'thiamin']
# ['acetaminophen', 'levothyroxine', 'lorazepam', 'multivitamin', 'senna', 'trazodone']
# ['unknown']
# ['antivert', 'aspirin', 'atorvastatin', 'eye', 'finasteride', 'forte', 'lisinopril', 'mvi', 'palmetto', 'pantoprazole', 'pred', 'prn', 'right', 'saw', 'tid', 'verapamil', 'xyzal', 'zaditor']
# ['nan']
# ['nan']
# ['allopurinol', 'bid', 'chloride', 'donepezil', 'furosemide', 'lisinopril', 'meq', 'pantoprazole', 'potassium', 'sotalol', 'warfarin', 'weekly']
# ['actos', 'amlodipine', 'hydrochlorthiazide', 'olmeprazole', 'olmesartan', 'onglyza', 'repaglinide', 'simvastatin', 'toujeo', 'trulicity', 'unit']
# ['nan']
# ['unknown']
# ['acid', 'ascorbic', 'aspirin', 'b', 'buprenorphine', 'celexa', 'coreg', 'doss', 'gabapentin', 'gel', 'guaifenesin', 'hydralazine', 'losartan', 'magnesium', 'melatonin', 'metolazone', 'miralax', 'oc', 'potassium', 'senna', 'tramadol', 'uvite', 'vitamin', 'vitamin b', 'voltaren', 'zinc']
# ['aspirin', 'depakote', 'gabapentin', 'loratidine', 'plus', 'prilosec', 'senna', 'seroquel', 'vitamin']
# ['unknown']
# ['nan']
# ['advair', 'albuterol', 'calcium', 'carbonate', 'cetirizine', 'cyclobenzaprine', 'fluticasone', 'guaifenesin', 'hfa', 'home', 'include', 'inhaler', 'ipratropium', 'lidocaine', 'medications', 'nasal', 'nebulizer', 'oxygen', 'prednisone', 'prescribed', 'solution', 'spray']
# ['colace', 'mobic', 'mvi', 'olanzapine', 'remeron', 'tylenol']
# ['casodex', 'mcg', 'multivitamin', 'naproxen', 'prilosec', 'synthroid', 'tylenol', 'zoloft']
# ['albuterol', 'amlopidine', 'aspirin', 'atorvastatin', 'drops', 'eye', 'gabapentin', 'hctz', 'hydroxyzine', 'lansoprazole', 'lasix', 'levalbuterol', 'losartan', 'meloxicam', 'norco', 'nystatin', 'preservision', 'prolia', 'refresh', 'spiriva', 'wixela']
# ['allopurinol', 'aspirin', 'bid', 'codine', 'er', 'fursemide', 'guaifenesin', 'h', 'isosorbide', 'levothyroxine', 'lm', 'metoprolol', 'mononitrate', 'nitroglycerin', 'po', 'prn', 'q', 'rosuvastatin', 'succinate', 'syrup']
# ['atenolol', 'dronabinol', 'furosemide', 'lamotrigine', 'levothyroxine', 'lisinopril', 'mirtazapine', 'pantoprazole']
# ['atropine', 'duoneb', 'erythromycin', 'ethylsuccinate', 'famotidine', 'guiafenesin', 'jevity', 'keppra', 'labetalol', 'lasix', 'proscar', 'valium']
# ['bid', 'cholecalciferol', 'ius', 'magnesium', 'oxide', 'vi']
# ['atorvastatin', 'bedtime', 'evening', 'every', 'eyes', 'gabapentin', 'hydralazine', 'lantus', 'lumigan', 'metolazone', 'omperazole', 'ophthalmic', 'prednisone', 'soln', 'torsemi', 'units']
# ['unknown']
# ['acid', 'aricept', 'bedtime', 'cero', 'coreg', 'day', 'ferrous', 'folidc', 'hydrochlorothizide', 'lexapro', 'lisinopril', 'methimazole', 'sr', 'sulfate', 'tablet', 'two', 'vite']
# ['nan']
# ['acetaminophen', 'albuterol', 'alprazolam', 'er', 'gabapentin', 'hfa', 'levothyroxine', 'linzess', 'mcg', 'metformin', 'oxybutynin', 'oxycodone', 'rx', 'tizanidine', 'trazodone']
# ['acetaminophen', 'every', 'give', 'hou', 'mouth', 'tablet']
# ['copd', 'inhalers', 'medications', 'nebulizers', 'unknown']
# ['acetate', 'aceteminophen', 'aerosol', 'amlodipine', 'atorvastatin', 'benzonatate', 'besylate', 'breath', 'calcium', 'citalopram', 'clonidine', 'clopidogrel', 'coreg', 'cozaar', 'diclofenac', 'docusate', 'fluticasone', 'hydrobromide', 'powder', 'renvela', 'sodium', 'umeclidin', 'vilant']
# ['acidophylis', 'asa', 'ativan', 'cranberry', 'duloxetine', 'guaufenisen', 'ibuprofen', 'miralax', 'tramadol', 'vitamin', 'zinc']
# ['acidophylis', 'albuterol', 'asa', 'c', 'cranberry', 'depakote', 'evista', 'folic acid', 'inhaler', 'lasix', 'magnesium', 'melatonin', 'mineral', 'mirtazapine', 'mvi', 'oxide', 'pepcid', 'pericolace', 'simethicone', 'synthroid', 'vitamin', 'vitamin c', 'xarelto', 'zinc', 'zoloft']
# ['acetaminophen', 'asa', 'atorvastatin', 'calcium', 'ceftriaxone', 'docusate', 'famotidine', 'hydrocodone', 'levothyroxine', 'mcg', 'senna']
# ['nan']
# ['nan']
# ['nan']
# ['acetaminophen', 'aspirin', 'con', 'cream', 'docusate', 'eliquis', 'emu', 'finasteride', 'fluticasone', 'furosemide', 'joint', 'klor', 'melatonin', 'muscle', 'nortriptyline', 'pantoprazole', 'relief', 'simvastatin', 'sinemet', 'synthroid', 'tamsulosin', 'tums', 'vitamin', 'vitamin b']
# ['acetaminophen', 'capsule', 'coumadin', 'furosemide', 'kcal', 'lasix', 'liqd', 'nutren', 'nutritional', 'senna', 'senokot', 'spironolacto', 'sulfate', 'supplements', 'tab', 'tablet', 'tylenol', 'warfarin', 'zinc']
# ['amiodarone', 'amlodipine', 'besylate', 'bid', 'clonid', 'cozaar', 'hcl', 'hydralazine', 'losartan', 'memantine', 'metoprolol', 'namenda', 'norvasc', 'potassium', 'qd', 'tablet', 'tartrate', 'tid']
# ['amlodipine', 'aspirin', 'besylate', 'chewable', 'cva', 'day', 'g', 'give', 'liquid', 'minerals', 'multiple', 'multivitamin', 'norvasc', 'one', 'prophylaxis', 'supplement', 'tablet', 'time', 'tube', 'via', 'vitamins']
# ['amlodipine', 'besylate', 'capsule', 'day', 'gabapentin', 'give', 'hold', 'hr', 'hypertension', 'losartan', 'neuralgia', 'norvasc', 'one', 'orally', 'potassium', 'sbr', 'tablet', 'time']
# ['nan']
# ['unknown']
# ['unknown']
# ['amlodipine', 'asa', 'lisinopril', 'paxil']
# ['aspirin', 'clopidogrel', 'dexamethasone', 'dilatin', 'keppra', 'pantoprazole', 'plaxis', 'tramadol', 'vimpat']
# ['unknown']
# ['nan']
# ['allopurinol', 'amlodipine', 'eliquis', 'er', 'kcl', 'lasix', 'lyrica', 'mcg', 'meq', 'metoprolol', 'pravstatin', 'succinate', 'vit']
# ['bid', 'caps', 'dilantin', 'dm', 'dvt', 'eliquis', 'hyperlipidemia', 'lipitor', 'metformin', 'phenobarbital', 'po', 'qd', 'qhs', 'seizure']
# ['acetonide', 'apply', 'b', 'cream', 'day', 'january', 'loperamide', 'needed', 'per', 'po', 'tab', 'taken', 'triamcinolone', 'tylenol', 'vitamin']
# ['nan']
# ['nan']
# ['nan']
# ['lasix', 'metoprolol', 'tamsulosin', 'vitamin', 'warfarin']
# ['albuterol', 'allopurinol', 'amiodorone', 'budesonide', 'carb', 'chlorhexadine', 'clonidine', 'eliquis', 'gluconate', 'glycol', 'ipratopium', 'lantus', 'lasix', 'loratadine', 'magnesium', 'melatonin', 'metolazone', 'metoprolol', 'nepro', 'oxide', 'polyethylene', 'stea', 'tartrate', 'vitamin c']
# ['atrovastatin', 'bisulfate', 'calcium', 'capsule', 'cholecalclfer', 'clopidogrel', 'cobalamin', 'colace', 'cyano', 'famotidine', 'gilmepiride', 'hci', 'l', 'loperamide', 'mcg', 'melatonin', 'tablet', 'unit']
# ['allopurinol', 'amlopidine', 'asa', 'er', 'furosemide', 'glyburide', 'kcl', 'losartan', 'meq', 'metoprolol', 'pravastatin']
# ['asa', 'atorvastatin', 'benazepril', 'carvedilol', 'dose', 'famotidine', 'hospital', 'list', 'nitrostat', 'per', 'prn', 'sl', 'unspecified']
# ['nan']
# ['acidophilus', 'albuterol', 'alopurinol', 'apixaban', 'aspirin', 'budesonide', 'fish', 'formoter', 'furosemide', 'lactobacillus', 'levothyroxine', 'metolazone', 'metoprolol', 'oil', 'pantoprazole', 'potassium', 'terazosin']
# ['amlodipine', 'dexamethasone', 'drink', 'ensure', 'losartan', 'supplement']
# ['acetate', 'bid', 'calcium', 'coreg', 'ferrlecit', 'heparin', 'imdur', 'mircera', 'q', 'qd', 'qhd', 'qid', 'tiw', 'w', 'zoloft']
# ['far', 'know', 'none']
# ['amlodipine', 'atorvastatin', 'furosemide', 'gabapentin', 'glipizide', 'loratadine', 'losartan', 'metformin', 'metoprolol', 'omeprazole', 'trulicity']
# ['acetaminophen', 'acyclovir', 'adult', 'codeine', 'levothyroxine', 'multivitamin', 'one', 'prn', 'vitamin', 'vitamin b']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['unsure']
# ['acetaminophen', 'bisacodyl', 'constipation', 'covid', 'every', 'hours', 'insert', 'mcg', 'mrna', 'needed', 'pain', 'pfizer', 'rectally', 'suppository', 'suspension', 'vaccine']
# ['nan']
# ['albumin', 'ceftriaxone', 'day', 'dexmedetomodine', 'event', 'furosemide', 'hospital', 'kcl', 'lactulose', 'meds', 'midodrine', 'octreotide', 'pantoprazole', 'rifaximin']
# ['multiple', 'unknown']
# ['nan']
# ['nan']
# ['unknown']
# ['albuterol', 'fluticasone', 'hydrochlorothiazide', 'losartan', 'nasal', 'spray']
# ['ativan', 'hospice', 'morphine', 'trazodone', 'tylenol']
# ['nan']
# ['nan']
# ['nan']
# ['eliquis', 'lasix', 'metoprolol']
# ['diclofenac']
# ['nan']
# ['nan']
# ['unknown']
# ['benazepril', 'crestor', 'gabapentin', 'norvasc', 'po', 'toprol', 'xl']
# ['nan']
# ['albuterol', 'amoxicillan', 'cetirizine', 'cg', 'diphenhydran', 'drop', 'fluticasone', 'glycol', 'haloperidol', 'hfa', 'lactulose', 'mcg', 'methyldredn', 'neomycin', 'polyeth', 'polymyxin', 'prn', 'sertraline']
# ['unknown']
# ['clopidogrel', 'gabapentin', 'lexapro', 'prilosec', 'skin', 'synthroid', 'test', 'tuberculin', 'vitamin', 'vitamin c', 'zinc']
# ['aspirin', 'benedryl', 'centrum', 'detrol', 'donepezil', 'farxiga', 'gabapentin', 'hctz', 'losartan', 'macrobid', 'memantine', 'metformin', 'prilosec', 'risperidone', 'tylenol', 'vitamin', 'vitamin b', 'zocor']
# ['levsin', 'morphine', 'norco', 'sulfate']
# ['allegra', 'allopurinol', 'chloride', 'dexamethasone', 'eliquis', 'sodium', 'synthroid', 'trazadone', 'tylenol', 'vitamin', 'vitamin c', 'zinc']
# ['alprazolam', 'amlodipine', 'cozaar', 'lexapro', 'metoprolol', 'tylenol']
# ['none']
# ['citalopram', 'divalproex', 'levothyroxine']
# ['advair', 'asa', 'bystolic', 'crestor', 'diskus', 'fish', 'multivitamin', 'oil', 'qzemoic', 'started', 'subq', 'vitamin e', 'weekly']
# ['atorvastatin', 'bid', 'furosemide', 'iuqd', 'mgqd', 'omeprazole', 'pobid', 'propanolol', 'qd', 'vitamin', 'warfarin']
# ['nan']
# ['unknown']
# ['nan']
# ['none']
# ['caller', 'know', 'yes']
# ['acetaminophen', 'aspercreme', 'cholecalciferol', 'clozapine', 'cobalamin', 'cyano', 'er', 'extended', 'guaifenesin', 'hour', 'lidocaine', 'mcg', 'mirtazapine', 'mucinex', 'patch', 'release', 'remeron', 'tablet']
# ['nan']
# ['acetaminophen', 'bisacodyl', 'capsule', 'concentrate', 'er', 'extended', 'guaifenesin', 'h', 'hour', 'morphine', 'mucinex', 'prednisone', 'probiotic', 'product', 'release', 'risaquad', 'solution', 'sulfate', 'suppository', 'tablet']
# ['amlodipine', 'aspirin', 'atenolol', 'calcium', 'colase', 'fish', 'hydrochlorathiazide', 'lisinopryl', 'methimazole', 'oil', 'trazadone']
# ['aspirin', 'atorvastatin', 'b', 'furosemide', 'iu', 'mcg', 'metoprolol', 'norvasc', 'renvela', 'vitamin', 'vitamin b']
# ['acetaminophen', 'amoxicillin', 'aspirin', 'chloride', 'chondroitin', 'cozaar', 'furosemide', 'furosemids', 'glucosamine', 'meq', 'multivitamin', 'potassium', 'tab', 'tamsulosin', 'zofran']
# ['nan']
# ['bismol', 'cholestyramine', 'duloxetine', 'fiber', 'haloperidol', 'hyoscyamine', 'lisinopril', 'lorazepam', 'metoprolol', 'morphine', 'nystatin', 'pepto', 'powder', 'seroquel', 'spiriva', 'symbicort', 'tramadol', 'tylenol', 'vistaril', 'zolpidem']
# ['nan']
# ['atenolol', 'atorvastatin', 'metformin']
# ['nan']
# ['crush', 'day', 'feeding', 'food', 'milk', 'mix', 'naproxen', 'orally', 'pm', 'seroquel', 'suspension', 'tablet', 'thru', 'tube', 'water']
# ['acetylcysteine', 'albuterol', 'ampul', 'bedtime', 'budesonide', 'day', 'divalproex', 'er', 'give', 'h', 'inhale', 'ipratropium', 'mouth', 'neb', 'orally', 'sdv', 'sod', 'solution', 'sr', 'tab', 'tablet', 'two', 'u', 'ud']
# ['anoro', 'aspirin', 'atorvastatin', 'flextouch', 'gabapentin', 'hcl', 'inhaler', 'insulin', 'melatonin', 'men', 'multivitamin', 'pen', 'pioglitazone', 'risperidone', 'sertraline', 'symtuza', 'tresiba', 'victoza']
# ['bactrim', 'crestor', 'eliquis', 'famotidine', 'fluconazole', 'folic acid', 'gabapentin', 'gas', 'labetalol', 'miralax', 'prednisone', 'x']
# ['copaxone']
# ['cd', 'chloride', 'diltiazem', 'drops', 'eye', 'gabapentin', 'glycol', 'hydroxychloroquine', 'levothyroxine', 'omeprazole', 'oritavancin', 'potassium', 'propylene', 'sertraline']
# ['amlodipine', 'aspirin', 'besylate', 'finasteride', 'flomax', 'pepcid', 'plus', 'pravastatin', 'seroquel', 'sodium', 'stress', 'tab', 'zinc']
# ['nan']
# ['facility', 'given', 'nursing', 'sure', 'vaccine']
# ['nan']
# ['none']
# ['aspirin', 'atorvastatin', 'calcium', 'clopidogrel', 'dihydrochloride', 'donepezil', 'fumarate', 'glarg', 'insulin', 'lispro', 'memantine', 'pantoprazole', 'pramipexole', 'prednisone', 'propranolol', 'quetiapine']
# ['nan']
# ['acetaminophen', 'acid', 'albuterol', 'amlodipine', 'ascorbic', 'atorvastatin', 'baclofen', 'buspirone', 'calcium', 'carbonate', 'cholecalciferol', 'dexmedetomidine', 'diltiazem', 'docusate', 'esomeprazole', 'famotidine', 'fentanyl', 'fluticasone', 'ga', 'ipratropium', 'vitamin']
# ['blood', 'insulin', 'medication', 'pressure']
# ['blood', 'medication', 'prescription', 'pressure']
# ['unknown']
# ['unknown']
# ['nan']
# ['carvedilol', 'citalopram', 'olanzapine', 'phenytion']
# ['amlodipine', 'furosemide', 'lisinopril', 'loratadine', 'meclizine', 'omeprazole']
# ['gabapentin', 'glipizide', 'medical', 'metformin', 'per', 'records', 'reviewed']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['amiodarone', 'asa', 'chloride', 'er', 'lasix', 'lisinopril', 'meq', 'metoprolol', 'namenda', 'potassium', 'protonix', 'senna', 'simvastatin', 'xr']
# ['unknown']
# ['nan']
# ['unknown']
# ['acetaminophen', 'aspirin', 'biscodyl', 'ferrous', 'magnesia', 'milk', 'miralax', 'pepcid', 'powder', 'prevident', 'propafenone', 'sulfate', 'suppository']
# ['nan']
# ['clonazepam', 'flomax', 'flunisolide', 'mag', 'melatonin', 'milk', 'miralax', 'omeprazole', 'sertraline', 'soln', 'tylenol']
# ['nan']
# ['atorvastatin', 'cl', 'diphenhydramine', 'e', 'eyes', 'furosemide', 'gabapentin', 'hcl', 'healthy', 'imodium', 'isosorbide', 'jantoven', 'lutein', 'metoprolol', 'minerals', 'mononitrate', 'nitroglycerin', 'potassium', 'succinate', 'vitamin c']
# ['atorvastatin', 'dialy', 'eliquis', 'humalog', 'levemir', 'metoprolol', 'pantoprazole', 'plavix', 'prozac', 'renagel', 'trazodone', 'tylenol', 'vite']
# ['albuterol', 'citrate', 'docusate', 'duloxetine', 'existing', 'folic acid', 'glycol', 'hydroxychloroquine', 'inhaler', 'multi', 'nystatin', 'pain', 'pandemic', 'polyethylene', 'powder', 'pre', 'prescription', 'probiotic', 'pump', 'senna', 'symbicort', 'tofacitinib', 'tums', 'vitamin']
# ['aspirin', 'certe', 'depakote', 'famotidine', 'keppra', 'metoprolol', 'mylanta', 'rocephin', 'sprinkles', 'trazodone', 'tricor', 'tylenol', 'vit', 'vite', 'zocor']
# ['amlodipine', 'duloxetine', 'famotidine', 'hydocortisone', 'lisinopril', 'marijuana', 'medical', 'mertazapine', 'monolucast', 'oxymorphone', 'simvastatin']
# ['apap', 'aquaiphor', 'ativan', 'cough', 'dulcolax', 'duo', 'flomax', 'lasix', 'levsin', 'mom', 'morphine', 'muscle', 'neb', 'oint', 'prednisone', 'protonix', 'rub', 'senna', 'syryp', 'tums']
# ['haloperidol', 'lorazepam', 'morphine']
# ['dehydrochloride', 'levocetirizine', 'nebivolol', 'pantoprazole']
# ['aspirin', 'atorvastatin', 'folic acid', 'glipizide', 'lisinopril', 'metformin', 'metoprolol', 'nephrocaps', 'omeprazole', 'pioglitazone', 'rivaroxaban', 'sitagliptin', 'tadalafil']
# ['aspirin', 'baby']
# ['albuterol', 'fentanyl', 'hydrocodone']
# ['acetaminophen', 'albuterol', 'anxiety', 'arnicare', 'cobalamin', 'cream', 'cyano', 'diazepam', 'ergocalciferol', 'fluoxetine', 'h', 'inhaler', 'pain', 'po', 'prn', 'puff', 'q', 'units']
# ['unknown']
# ['capsule', 'cranberry', 'lactobacillus', 'multivitamins', 'tablet']
# ['austedo', 'clonazepam', 'mirtazapine', 'omeprazole', 'risperdal', 'senna', 'seroquel']
# ['alendronate', 'arthritis', 'aspirin', 'buspirone', 'calcitonin', 'calcium', 'capsule', 'cardedilol', 'day', 'every', 'hcl', 'nostril', 'per', 'q', 'sodium', 'solution', 'spray', 'sunday', 'tab', 'time', 'units', 'via']
# ['bid', 'capsule', 'coreg', 'hytrin', 'lasix', 'levothyroxine', 'lipitor', 'lisinopril', 'mcg', 'pantopra', 'phenobarbital', 'po', 'tablet']
# ['unknown']
# ['duloxetine', 'pantoprazole', 'tramadol', 'vesicare']
# ['attached', 'list', 'med', 'see']
# ['asa', 'demedex', 'jardiance', 'levimir', 'lipitor', 'lisinopril', 'metformin', 'metoprolol']
# ['aspirin', 'benztropine', 'cetirizine', 'chlorpromazine', 'clonidine', 'cp', 'divalproex', 'dr', 'ec', 'folic acid', 'handihal', 'hcl', 'mcg', 'mes', 'propranolol', 'spiriva', 'tablet', 'trazodone', 'vita b', 'xarelto']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['novolog']
# ['nan']
# ['nan']
# ['amlodipine', 'day', 'dr', 'metformin', 'omeprazol', 'simvastatin']
# ['nan']
# ['nan']
# ['artificial', 'aspirin', 'chloride', 'clear', 'dok', 'ensure', 'er', 'metoprolol', 'miralax', 'pepcid', 'plus', 'potassium', 'tartrate', 'tears', 'tramadol', 'vitamin c']
# ['contact', 'facility', 'home', 'medications', 'nursing', 'patient', 'please', 'resident', 'scheduled']
# ['acids', 'advair', 'albuterol', 'aspirin', 'atorvastatin', 'boniva', 'cobalamin', 'combivent', 'cyano', 'ergocalciferol', 'famotidine', 'fatty', 'hydrocodone', 'levothyroxine', 'loratadine', 'omega', 'oxide', 'prevacid', 'respimat', 'risperdal', 'sennoside', 'sertraline', 'spiriva', 'zinc']
# ['nan']
# ['unsure']
# ['nan']
# ['nan']
# ['aspirin', 'atorvastatin', 'cero', 'cl', 'desonide', 'docusate', 'donepezil', 'ec', 'eliquis', 'fluticasone', 'hcl', 'latanoprost', 'levothyroxine', 'losartan', 'melatonin', 'os', 'potas', 'potassium', 'prop', 'senior', 'sodium', 'torsemide', 'unit', 'vitamin', 'vitamin b', 'vite']
# ['atorv', 'cholecalciferol', 'day', 'docusate', 'hcl', 'hrs', 'levothyroxine', 'mcg', 'metoclopramide', 'needed', 'q', 'sennosides', 'senokot', 'sodium', 'tablet', 'tabs', 'tylenol', 'unit']
# ['clopidogrel', 'depakote', 'flomax', 'imdur', 'lexapro', 'lisinopril', 'metoprolol', 'proscar', 'seroquel', 'succinate', 'trazadone', 'xr']
# ['aspirin', 'baclofen', 'bid', 'ec', 'es', 'garlic', 'iu', 'lasix', 'lipitor', 'lisino', 'metformin', 'multi', 'multivitamin', 'oil', 'po', 'qd', 'senna', 'tablet', 'tylenol', 'vitamin']
# ['nan']
# ['unknown']
# ['areds', 'calcium', 'carbonate', 'cholecalciferol', 'ezetimibe', 'insulin', 'lantus', 'levothyroxine', 'melatonin', 'olanzapine', 'pantoprazole', 'preservision', 'senokot', 'sitagliptin']
# ['acyclovir', 'apply', 'area', 'available', 'capsule', 'corn', 'death', 'deleted', 'due', 'facility', 'finger', 'hand', 'latest', 'list', 'medication', 'powder', 'rd', 'record', 'red', 'right', 'starch', 'supply', 'th', 'us']
# ['unknown']
# ['aspirin', 'hospice', 'levothyroxine', 'medications', 'multivitamins', 'possible', 'senna']
# ['unknown']
# ['atrovastatin', 'calcium', 'chloride', 'fluoxetine', 'hcl', 'lisinoprilm', 'lyrica', 'magnesium', 'meq', 'metoprolol', 'omprazole', 'oxide', 'potassium', 'tartrate']
# ['haloperidol', 'lorazepam', 'morphine']
# ['nan']
# ['acetaminophen', 'citalopram', 'docusate', 'hospice', 'may', 'medications', 'received', 'senna', 'seroquel', 'wellbutrin']
# ['ernesto', 'gabapentin', 'lasix', 'morphine', 'omeprazole', 'oxycodone']
# ['nan']
# ['nan']
# ['asa', 'ativan', 'baby', 'bicarbonate', 'isosorbide', 'lipitor', 'mealatonin', 'metoprolol', 'mutli', 'nexium', 'nitrostat', 'norvasc', 'paracalcitrol', 'pepcid', 'prn', 'sodium', 'trospium', 'tums', 'vit', 'vitamin', 'vitamin b']
# ['nan']
# ['unknown']
# ['albuterol', 'arip', 'aspirin', 'budesonide', 'capsule', 'cholecalciferol', 'diltiazem', 'docusate', 'furosemide', 'ibuprofen', 'ipratropium', 'levothyroxine', 'losartan', 'melatonin', 'nebulization', 'omeprazole', 'paroxetine', 'perforomist', 'sodium', 'solution', 'suspension']
# ['unknown']
# ['nan']
# ['nan']
# ['daughter', 'prescriptions', 'unaware']
# ['bedtime', 'bid', 'capsule', 'clonazepam', 'cranberry', 'er', 'hr', 'l', 'magnesia', 'mannose', 'metoprolol', 'milk', 'mirtazapine', 'po', 'prn', 'succinate', 'suspension', 'tab', 'tablet']
# ['albuterol', 'apap', 'calcium', 'carb', 'chew', 'every', 'hfa', 'hours', 'inha', 'inhalation', 'mcg', 'mouth', 'needed', 'one', 'puffs', 'tabs', 'take', 'two']
# ['artificial', 'aspirin', 'chf', 'day', 'drop', 'dry', 'eyes', 'furosemide', 'give', 'hypromellose', 'instill', 'lasix', 'mouth', 'needed', 'one', 'qid', 'solution', 'tablet', 'tears', 'time']
# ['acetaminophen', 'aspirin', 'calcium', 'carbidopa', 'carbonate', 'cholecalciferol', 'cream', 'fenofibrate', 'fluorouracil', 'fluticasone', 'folic acid', 'levodopa', 'miralax', 'nasal', 'nitroglycerin', 'prn', 'spray']
# ['amlodipine', 'cimetidine', 'day', 'donepezil', 'fluticasone', 'gabapentin', 'glipizide', 'losartan', 'memantine', 'metformin', 'nasal', 'spray']
# ['acetaminophen', 'amlodipine', 'calcium', 'carbonate', 'celebrex', 'glycol', 'irbesartan', 'lidocaine', 'loratadine', 'patch', 'polyethylene', 'pravastatin', 'prn', 'vitamin']
# ['medication', 'multiple']
# ['acetaminophen', 'amlodipine', 'bengay', 'bid', 'bisacodyl', 'clotrimazole', 'flonase', 'list', 'loratadine', 'lorazepam', 'md', 'med', 'melatonin', 'metoprolol', 'miralax', 'nitrostat', 'oxycodone', 'pra', 'prn', 'qid', 'scheduled', 'time', 'tums', 'vaccine', 'zofran']
# ['facility', 'home', 'notify', 'nursing', 'patient', 'please', 'resident']
# ['nan']
# ['amlodipine', 'apap', 'atorvastatin', 'bid', 'drop', 'drops', 'er', 'eye', 'gabapentin', 'glipizide', 'hs', 'lisinopril', 'metformin', 'naproxen', 'otc', 'prn', 'tid', 'timolol', 'tradjenta', 'trazodone']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['glipizide', 'metformin', 'warfarin']
# ['nan']
# ['amiodarone', 'apresoline', 'asa', 'calcitriol', 'coreg', 'fo', 'lvite', 'synth']
# ['fo', 'iron', 'lvite', 'neurontin', 'proamatine', 'rocaltrol', 'zifaxan']
# ['acetaminophen', 'aspirin', 'atorvastatin', 'bisacodyl', 'care', 'chlorhexidine', 'dermaseptin', 'eucerin', 'listerine', 'memantine', 'mva', 'ophthalmic', 'patch', 'periguard', 'rivastigmine', 'suspension', 'trileptal', 'vitamin', 'vitamin b', 'vitamin c', 'zinc']
# ['atorvastatin', 'avalide', 'citalopram', 'felodipine', 'metoprolol', 'omeprazole']
# ['nan']
# ['nan']
# ['nan']
# ['acid', 'ascorbic', 'carbidopa', 'clopidogrel', 'entacapone', 'finasteride', 'levodopa', 'multivitamin', 'plus', 'pravastatin', 'prevident', 'propranolol', 'rivaroxaban', 'tamsulosin']
# ['nan']
# ['nan']
# ['amiodarone', 'apixaban', 'atorvastatin', 'carvedilol', 'gabapentin', 'glargine', 'hfa', 'insulin', 'iron', 'lasix', 'levothyroxine', 'lidocaine', 'lispro', 'patch', 'percocet', 'protonix', 'sertraline', 'sulfate', 'ventolin', 'vitamin b']
# ['nan']
# ['unknown']
# ['nan']
# ['unknown']
# ['unknown']
# ['nan']
# ['albuterol', 'allopurinol', 'asa', 'chloride', 'diclofenac', 'diltiazem', 'furosemide', 'gel', 'metoprolol', 'potassium', 'tiotropium', 'topical']
# ['nan']
# ['alphagan', 'aricept', 'colace', 'depakote', 'gtts', 'levetiracetam', 'metoprolol', 'senna', 'tylenol']
# ['cl', 'er', 'hcl', 'hctz', 'lexapro', 'lisinopril', 'oxybutynin', 'tamulosin', 'trulicity', 'zetia']
# ['acetaminophen', 'aspirin', 'bisacodyl', 'coated', 'delayed', 'dulcolax', 'eliquis', 'enema', 'enteric', 'fleet', 'prn', 'rectal', 'release', 'suppository', 'ta', 'tablet', 'time']
# ['alendronate', 'amlodipine', 'artificial', 'aspirin', 'atorvastatin', 'benazepril', 'calcium', 'diclofenac', 'ezetimibe', 'glimeperide', 'hydrochlorothiazide', 'lacri', 'latanoprost', 'lidocaine', 'lube', 'medical', 'metformin', 'opthalmic', 'p', 'per', 'record', 'tears', 'topical', 'vitamin']
# ...
# ['acyclovir', 'calcium', 'chondroitin', 'citalopram', 'complex', 'dexamethasone', 'eliquis', 'glucosamine', 'lipitor', 'metoprolol', 'pantoprazole', 'vitamin b']
# ['apixaban', 'chlorhexidine', 'dakins', 'docusate', 'duoneb', 'humalog', 'hydroxyzine', 'levetiracetam', 'metroprolol', 'pantoprazole', 'santyl', 'tramadol', 'vitamin c', 'zinc']
# ['nan']
# ['amlodipine', 'dorzolamide', 'latanoprost', 'oxybutynin', 'timolol', 'travoprost']
# ['nan']
# ['air', 'inhaler', 'pro']
# ['', 'vitamins']
# ['nan']
# ['daughter', 'none', 'noted', 'patient', 'per']
# ['aspirin', 'b', 'biotin', 'c', 'potassium', 'statin', 'vitamins b']
# ['augmentin', 'axetil', 'cefurozime', 'changed', 'day', 'ear', 'infection', 'oral', 'tablet', 'vaccination']
# ['nan']
# ['aspirin', 'atorvastatin', 'c', 'e', 'lipitor', 'metoprolol']
# ['nan']
# ['atenolol', 'rosuvastatin']
# ['aspirine', 'eliquis', 'isosorbide', 'metoprolol', 'simvastatin']
# ['unknown']
# ['nan']
# ['nan']
# ['nan']
# ['chlorthalidone', 'extended', 'losartan', 'meloxicam', 'metoprolol', 'mil', 'oral', 'potassium', 'release', 'succinate', 'tablet']
# ['nan']
# ['azithromycin', 'meclizine', 'zyrtec']
# ['nan']
# ['unknown']
# ['nan']
# ['none']
# ['colcrys', 'lisinopril']
# ['tikosyn', 'warfarin']
# ['aspirin', 'bedtime', 'cl', 'divalproex', 'er', 'furosemide', 'levothyroxine', 'mcg', 'melatonin', 'meq', 'metoprolol', 'p', 'potassium', 'pravastatin', 'sod', 'sodium', 'tartrate']
# ['nan']
# ['zoloft']
# ['nan']
# ['nan']
# ['nan']
# ['capsule', 'day', 'glycopyrrolate', 'hydroxyzine', 'itching', 'lisinopril', 'metformin', 'mouth', 'needed', 'robinul', 'tablet', 'take', 'vistaril', 'zestril']
# ['nan']
# ['warfarin']
# ['nan']
# ['unknown']
# ['aspirin', 'fish', 'metoprolol', 'multivitamin', 'oil', 'vitamin b', 'vitamin c', 'zinc']
# ['nan']
# ['nan']
# ['nan']
# ['acid', 'acidophillus', 'alendronate', 'amlodipine', 'ascorbic', 'atorvastatin', 'calcium', 'chew', 'cya', 'floranex', 'fosamax', 'lactobacillus', 'lipitor', 'norvasc', 'oscal', 'tablet', 'unit', 'vitamin']
# ['amaryl', 'aspirin', 'atorvastatin', 'bid', 'claritin', 'lyrica', 'metformin', 'multivitamin', 'onglyza', 'ranitidine']
# ['alendronate', 'atenolol', 'b', 'calcium', 'con', 'eliquis', 'klor', 'levothyroxine', 'metoclopramide', 'omeprazole', 'pravastatin', 'propafenone', 'tums', 'verapamil']
# ['fenofibrate', 'irbesartan']
# ['nan']
# ['atorvastatin', 'b', 'bicalutamide', 'calcium', 'finasteride', 'furosemide', 'metropolol', 'potassium']
# ['unknown']
# ['amloditin', 'aspirin', 'dicyclamine', 'formin', 'glutizide', 'metaporlal', 'multi', 'pregnazone', 'softener', 'stool', 'styolato', 'traceva', 'u', 'vitamin', 'xanax']
# ['nan']
# ['albuterol', 'enalapril', 'hctz', 'nebulizer', 'prednisone']
# ['apple', 'atenolol', 'bark', 'cider', 'cinnamon', 'cream', 'current', 'glucotrol', 'included', 'lisinopril', 'lofibra', 'medications', 'metformin', 'multivitamin', 'nystatin', 'pioglitazone', 'potassium', 'vinegar']
# ['nan']
# ['nan']
# ['unknown']
# ['nan']
# ['unknown']
# ['nan']
# ['nan']
# ['fenobrite', 'glipizide', 'hcl', 'januvia', 'lisinopril', 'metformin']
# ['unknown']
# ['day', 'losartan', 'potassium']
# ['nan']
# ['unknown']
# ['nan']
# ['nan']
# ['acitretin', 'aspirin', 'calcitriol', 'clopidogrel', 'duloxetine', 'ferrous', 'furosemide', 'heptahydrate', 'hydrochloride', 'isosorbide', 'lamotrigine', 'lantus', 'metformin', 'metoprolol', 'nos', 'pantoprazole', 'sulfate', 'vitamin', 'vitamin b']
# ['nan']
# ['nan']
# ['blood', 'know', 'med', 'name', 'pressure']
# ['nan']
# ['nan']
# ['none']
# ['perscriptions']
# ['allergy', 'meds', 'metformin', 'otc']
# ['unkonwn']
# ['albuterol', 'citalopram', 'diflucan', 'ellipta', 'inh', 'ketorolac', 'levaquin', 'metoprolol', 'neurontin', 'oxycodone', 'pantoprazole', 'percocet', 'trelegy']
# ['nan']
# ['hydrocerin', 'minipress', 'temovate', 'vistaril']
# ['certrizine', 'naproxen', 'trazodone']
# ['atorvastatin', 'coreg', 'cymbalta', 'ferrous', 'lasix', 'levothyroxine', 'lisinopril', 'norvasc', 'sulfate']
# ['none']
# ['counter', 'ibuprofen']
# ['amlodipine', 'atorvastatin', 'bupropion', 'escitalopram', 'furosemide', 'lantus', 'levothyroxine', 'metoprolol', 'mirtazepine', 'pantoprazole']
# ['diltiazem', 'fosinopril', 'glimepiride', 'metformin']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['none']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['finasteride', 'tamsulosin']
# ['unknown']
# ['amitriptyline', 'amlodipine', 'bisoprolol', 'buspirone', 'donepezil', 'hydrochlorothiazide', 'np', 'paxil', 'thyroid', 'zolpidem']
# ['unk']
# ['allopurinol', 'aspirin', 'atorvastatin', 'baby', 'buspirone', 'clopidogrel', 'ezetimibe', 'finasteride', 'insulin', 'isosorbide', 'lisinopril', 'melatonin', 'mononitrate', 'nifedipine', 'night', 'sertraline']
# ['acetaminophen', 'amlodipine', 'besylate', 'fr', 'h', 'hcl', 'hydralazine', 'levothyroxine', 'mcg', 'melatonin', 'mo', 'po', 'prn', 'q', 'tid', 'zemplar']
# ['avastin', 'cancer', 'colon', 'irinotecan']
# ['nan']
# ['unknown']
# ['unk']
# ['ferrous', 'multivitamin', 'pediatric', 'sulfate']
# ['none']
# ['ibuprofen']
# ['acetaminophen', 'albuterol', 'aspirin', 'budesonide', 'clopidogrel', 'formoterol', 'hydrochlorothiazide', 'lisinopril', 'liters', 'oxygen', 'rivaroxaban', 'simvastatin', 'tiotropium']
# ['metformin', 'statin']
# ['atorvastatin', 'glipizide', 'hcl', 'losartan', 'metformin', 'potassium', 'trulicity']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['albuterol', 'aspirin', 'atorvastatin', 'calcium', 'carb', 'chew', 'chloride', 'ec', 'fe', 'hcl', 'hfa', 'inhaler', 'ketotifen', 'mcg', 'meclizine', 'multivitamin', 'nasal', 'ointment', 'ophthalmic', 'puralube', 'senna', 'sodium', 'spray']
# ['nan']
# ['nan']
# ['unk']
# ['nan']
# ['unk']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['actuation', 'asiprin', 'atorvastatin', 'bid', 'bumetanide', 'calcitriol', 'carvedilol', 'catheter', 'clobidogrel', 'diskus', 'drops', 'exit', 'flovent', 'gentamicin', 'inhale', 'mcg', 'powder', 'qd', 'site', 'tab', 'xweek']
# ['unknown']
# ['air', 'alprazolam', 'aspirin', 'breo', 'centrum', 'pro', 'warfin']
# ['unknown']
# ['propanol']
# ['nan']
# ['acid', 'apixaban', 'ascorbic', 'bid', 'chlorhexidine', 'clonidine', 'conc', 'diltiazem', 'fluconazole', 'g', 'gabapentin', 'h', 'hcl', 'insulin', 'peridex', 'q', 'qhs', 'solution', 'vitamin c']
# ['nan']
# ['nan']
# ['none']
# ['nan']
# ['nan']
# ['amlodipine', 'atorvastatin', 'coreg', 'depakote', 'plavix', 'trazodone']
# ['blood', 'doesnt', 'know', 'meds', 'name', 'pressure']
# ['nan']
# ['nan']
# ['acetaminophen', 'amiodarone', 'apixaban', 'aspirin', 'atorvastatin', 'docusate', 'furosemide', 'ibuprofen', 'memantine', 'metoprolol', 'multivitamin', 'pantoprazole', 'plus', 'risperidone', 'sertraline', 'sodium', 'thera', 'trazodone']
# ['atorvastatin', 'calcium', 'cobalamin', 'cyano', 'divalproex', 'donepezil', 'eliquis', 'escitalopram', 'fish', 'fluconazole', 'levothyroxine', 'oil', 'pantoprazole', 'tylenol']
# ['nan']
# ['birth', 'control']
# ['acetaminophen', 'acidophilus', 'albuterol', 'azithromycin', 'bisacodyl', 'calcium', 'carbonate', 'cholecalciferol', 'combivent', 'ferrous', 'finasteride', 'furosemide', 'hydralazine', 'ipratropium', 'lactobacillus', 'lidocaine', 'lidoderm', 'losart', 'mucinex', 'respimat', 'sulfate']
# ['marijuana']
# ['allopurinol', 'amoxicillin', 'apixaban', 'appt', 'aspirin', 'bid', 'caps', 'cholecalciferol', 'coenzyme', 'day', 'dental', 'eliquis', 'following', 'po', 'prior', 'q', 'qhs', 'units', 'vitamin']
# ['eliquis']
# ['unk']
# ['nan']
# ['nan']
# ['around', 'changing', 'hospital', 'medications', 'mom', 'sure', 'time']
# ['albuterol', 'amlodipine', 'aspirin', 'calcium', 'colace', 'miralax', 'mucinex', 'synthroid', 'vitamin']
# ['benzoyl', 'ibuprofen', 'patches', 'peroxide', 'salonpas']
# ['nan']
# ['nan']
# ['nan']
# ['gabapentin']
# ['none']
# ['acetaminophen', 'amlodipine', 'aspirin', 'atorvastatin', 'buprenorphine', 'carvedilol', 'cream', 'diclofenac', 'docusate', 'gabapentin', 'gel', 'glargine', 'heparin', 'hydralazine', 'insulin', 'levetiracetam', 'lidocaine', 'lispro', 'ondansetron', 'patch', 'rena', 'sodium']
# ['amlodipine', 'aspirin', 'atorvastatin', 'bayer', 'er', 'hydrochlorothiazide', 'lorazepam', 'metoprolol', 'needed', 'succinate', 'tablet']
# ['amlodipine', 'atorvastatin', 'colchicine', 'dofetilide', 'furosemide', 'lisinopril', 'metroprolol', 'terazosin', 'warfarin']
# ['avocado', 'men', 'multi', 'vitamins', 'water']
# ['aspirin', 'divalporex', 'fish', 'glargine', 'hcl', 'hyrroxyzine', 'levothryroxine', 'lisinopril', 'magnesium', 'metformin', 'metoprolol', 'na', 'oil', 'prazosin', 'rovastatin', 'seroquil', 'tartrate', 'vitamin']
# ['abuterol', 'alendronate', 'atorvastatin', 'bumetanide', 'carvedilol', 'coq', 'eliquis', 'farxiga', 'furosemide', 'gabapentin', 'glipizide', 'metazalone', 'multivitamins', 'symbicort', 'tamulosin', 'torsemide']
# ['tbd']
# ['nan']
# ['albuterol', 'fluticasone', 'losartan', 'oxycodone', 'prednisone']
# ['acid', 'atrorvastatin', 'eliquis', 'folice', 'lisinopril', 'metformin', 'pantoprzole', 'paraxetine']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['yes']
# ['anastrozole', 'aspirin', 'bayer', 'dose', 'feosol', 'hydrochlorothiazide', 'lantanaprost', 'levothyroxine', 'losartan', 'low', 'potassium']
# ['aspirin', 'lasix', 'plavix', 'temazepam']
# ['amlodipine', 'anastrozol', 'eliquis', 'lexapro', 'losartan', 'metoprolol']
# ['known']
# ['amaryl', 'atorvastatin', 'carvedidol', 'famotidine', 'furosemide', 'isosorbide', 'januvia', 'prozac', 'risperidone', 'synthroid', 'tamsulosima']
# ['unknown']
# ['acetaminophen', 'actuation', 'acyclovir', 'albuterol', 'alum', 'hfa', 'hydroxide', 'inhaler', 'mag', 'mcg', 'nebulizer', 'proventil', 'solution', 'tablet', 'tylenol', 'ventolin', 'zovirax']
# ['nan']
# ['carvedilol', 'folic acid', 'levoxin', 'lipitor', 'metformin', 'paxin', 'plavix', 'prednisone', 'temazepam']
# ['acarbose', 'acid', 'ascorbic', 'b', 'caps', 'cholecalciferol', 'cobalamin', 'cyano', 'fo', 'folic acid', 'furosemide', 'lasix', 'lvite', 'mcg', 'precose', 'tablet', 'ut', 'vitamin', 'vitamin b', 'vitamin c']
# ['acid', 'bid', 'caltrate', 'claritin', 'every', 'fenofibric', 'fish', 'hours', 'lipi', 'metformin', 'needed', 'norco', 'oil', 'plus', 'qd', 'synthroid', 'tab', 'tablet', 'vitamin', 'zyloprim']
# ['aware', 'report', 'source']
# ['nan']
# ['aricept', 'ferrous', 'folic acid', 'lasix', 'losartan', 'metformin', 'multivitamins', 'sulfate', 'zoloft']
# ['nan']
# ['allopurinol', 'bystolic', 'losartan', 'warfarin']
# ['nan']
# ['blood', 'cholesterol', 'extensive', 'oxygen', 'pressure', 'supplemental', 'unknown', 'welbutrin']
# ['bipolar', 'medications', 'unknown']
# ['alprazolam', 'amlodipine', 'anxiety', 'aspirin', 'chewable', 'day', 'every', 'half', 'mouth', 'needed', 'norvasc', 'one', 'tab', 'tablet', 'take', 'xanax']
# ['nan']
# ['nan']
# ['none']
# ['none']
# ['gabapentin', 'nortriptaline', 'simvastatim']
# ['none']
# ['atorvastatin', 'buprenorphine', 'depakote', 'lithium', 'methotrexate', 'quetipaine']
# ['nan']
# ['nan']
# ['allopurinol', 'escitalopram', 'gabapentin', 'pm', 'senna', 'tab', 'x']
# ['nan']
# ['nan']
# ['amlodipine', 'besylate', 'chlorthalidone', 'hcl', 'losartan', 'meloxicam', 'metoprolol', 'pantoprazole', 'potassium', 'sodium', 'succinate', 'tadalafil', 'tamsulosin', 'xarelto']
# ['none']
# ['act', 'albuterol', 'aspirin', 'atorvastatin', 'b', 'budesonide', 'clopidogrel', 'dextromethorphan', 'doxycline', 'er', 'escitalopram', 'fluticasone', 'gabapentin', 'hga', 'ipratropium', 'le', 'mct', 'polistirex', 'prn']
# ['unknown']
# ['insulin', 'losartan', 'metoprolol', 'omeprazole', 'type']
# ['nan']
# ['aspirin', 'metoprolol']
# ['unknown']
# ['ondansetron']
# ['know']
# ['unknown']
# ['unknown']
# ['unknown']
# ['unknown']
# ['unknown']
# ['unknown']
# ['unknown']
# ['unknown']
# ['unknown']
# ['unk']
# ['nan']
# ['nan']
# ['compliant', 'medications', 'non', 'prescribed', 'reportedly', 'unknown']
# ['unknown']
# ['atorvastatin', 'cyclobenzaprine', 'hydroxyzine', 'lorsartan', 'vitamin b']
# ['acetaminophen', 'fish', 'garlic', 'levothyroxine', 'oil']
# ['nan']
# ['none']
# ['contraceptives', 'oral']
# ['nan']
# ['asa', 'cream', 'ec', 'flexeril', 'hydrocortisone', 'ibuprofen', 'lipitor', 'metformin', 'nizoral', 'shampoo', 'tabs', 'tadalafil', 'triamcinolone', 'vitamin c', 'xr']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['ferrous', 'folic acid', 'lorazepam', 'sulfate', 'temazepam']
# ['aspirin', 'baby', 'simvastatin', 'zoloft']
# ['albuterol', 'aricef', 'atrovent', 'galantamine', 'losartan', 'remeron', 'tid', 'vitamin']
# ['nan']
# ['nan']
# ['nan']
# ['unknown']
# ['nan']
# ['nan']
# ['artane', 'azithromycin', 'calcium', 'carbonate', 'dicyclomine', 'doxycycline', 'escitalopram', 'flovent', 'gabapentin', 'lansoprazole', 'melatonin', 'ondansetron', 'tedizolid']
# ['amlodipine', 'atenolol', 'flonase', 'hctz', 'losartan', 'metformin', 'simvastatin', 'vitamin']
# ['nan']
# ['nan']
# ['nan']
# ['mcg', 'per', 'tablet', 'vienva']
# ['nan']
# ['nan']
# ['nan']
# ['acetaminophen', 'actuation', 'adapter', 'aerosol', 'albuterol', 'co', 'dc', 'every', 'hfa', 'hours', 'inhal', 'inhaler', 'mcg', 'ng', 'prn', 'puffs', 'sulfate', 'tablet', 'tube']
# ['allopurinol', 'calcitriol', 'capsule', 'ceftriaxone', 'cozaar', 'diltiazem', 'er', 'extended', 'fluticasone', 'hcl', 'hour', 'inject', 'intramuscularly', 'mcg', 'propionate', 'reconstituted', 'release', 'sodium', 'solution', 'suspensio', 'tablet']
# ['names', 'unknown']
# ['amlodipine', 'clonazepam', 'eliquis', 'hydrocodone', 'insulin', 'lisinopril', 'metoprolol', 'pregabalin', 'pump', 'sertraline', 'trazodone']
# ['aciphex', 'aspirin', 'b', 'clindamycin', 'colace', 'complex', 'coq', 'fish', 'flomax', 'metformin', 'metoprolol', 'oil', 'pralvent', 'sg', 'shot', 'trulicity', 'vit', 'vit e']
# ['unknown']
# ['another', 'diuretic', 'hypertension', 'medication', 'pt', 'took', 'unknown']
# ['nan']
# ['also', 'blood', 'diabetes', 'fish', 'high', 'medicine', 'oil', 'pressure', 'took', 'vitamin c']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['amlodipine', 'atenolol', 'hydralazine', 'losartan', 'rosuvastatin', 'terazosin']
# ['nan']
# ['nan']
# ['acid', 'amlodipine', 'ascorbic', 'aspirin', 'baby', 'calcium', 'cosopt', 'levothyroxine', 'metoprolol', 'sertraline', 'tocopherol', 'vitamin c', 'vitamin e', 'xalatan']
# ['nan']
# ['nan']
# ['none']
# ['nan']
# ['provide']
# ['insulin', 'lipitor', 'vitamin', 'warfarin']
# ['celexa', 'chlorthalidone', 'xanax']
# ['unknown']
# ['nan']
# ['nan']
# ['artificial', 'claritin', 'cyclosporine', 'dextran', 'drop', 'emulsion', 'eyes', 'give', 'hcl', 'hypromellose', 'instill', 'melatonin', 'pf', 'senna', 'solution', 'tablet', 'tears', 'trazodone']
# ['plavix', 'xarelto']
# ['none']
# ['act', 'azelastine', 'capsule', 'celecoxib', 'citalopram', 'fexofenadine', 'fluticasone', 'hcl', 'hydrobromide', 'lovastatin', 'mcg', 'nasal', 'ophthalmic', 'oral', 'propionate', 'solution', 'suspension', 'tablet']
# ['albuterol', 'amlodipine', 'prazosin', 'simvastatin', 'sulfate']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['carvedilol', 'furesomide', 'spironolactone']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['atorvastatin', 'buspirone', 'carvedilol', 'clonidine', 'fluoxetine', 'metformin', 'risperidone']
# ['amitriptyline', 'elavil', 'hydrochloride', 'lisinopril', 'simvastatin', 'terbutaline', 'theophylline']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['albuterol', 'allergy', 'anoro', 'cetiriine', 'ellipta', 'hydrochloride', 'nasacort', 'prednisone']
# ['nan']
# ['nan']
# ['nan']
# ['asa', 'dabigatran', 'docusate', 'famotidine', 'fexofenadine', 'fluticasone', 'hctz', 'kcl', 'losartan', 'metoprolol', 'montelukast', 'omeprazole', 'pregabalin', 'ropinirole', 'simvastatin', 'telmisartan', 'trospium']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['acetaminophen', 'amlodipine', 'carvedilol', 'lisinopril', 'melatonin', 'memantine', 'quetiapine', 'terazosin', 'warfarin']
# ['nan']
# ['nan']
# ['calcium', 'cod', 'docusate', 'ergocalciferol', 'fexofenadine', 'furosemide', 'levothyroxine', 'liver', 'loratadine', 'melatonin', 'metoprolol', 'oil', 'ointment', 'triamcinolone', 'warfarin']
# ['unknown']
# ['nan']
# ['nan']
# ['nan']
# ['albuterol', 'amlodipine', 'methamphetamine', 'sertraline', 'user', 'zolpidem']
# ['chart', 'listed', 'meclizine', 'needed', 'otc', 'tylenol', 'vertigo']
# ['listed', 'none']
# ['nan']

# %%
meds_list = []
def parse_meds(t):
    try: _l = t.split(",")
    except: return
    for i in _l:
        if i not in meds_list:
            meds_list.append(i)
vd["OTHER_MEDS"].apply(parse_meds)
print(meds_list)
# Out:
# ['Lisinopril', ' Novolog', '', ' Lantus Solostar', ' Gabapentin', ' Glusosamine-chondrotin', ' Lanaoprost', ' Alphagan', ' Metoprol Tartrate', '  Colocrys. . as needed', ' Chlorthlidone.', 'Quietapine', ' Mertazipine', ' Hydrocodone', ' Fentanyl', 'Torsemide', ' Trazadone', ' Amitizide', ' Morphine Sulfate', ' Carbidoba-Levodopa', ' Prednisone', ' Potassium Chloride', ' Escalitapram', ' Incruse Ellipta', ' Mirtazipane', ' Clonazepam', ' Levothyroxine', 'Metoprolol-Tartrate', ' Latanoprost', ' Glipizide', ' Pravastatin', ' Metformin', ' Benaprezil', ' Potassium-Chloride', '- Invega Trenza 546mg Q3months  - Lithium 300mg BID - Oxybutynin 5mg QID - lipitor 20mg QHS  - cogentin 2mg BID  - Norvasc 5mg QD - Dyazide Capsule 37.5-25 MG (Triamterene-HCTZ) QD', 'Albuteral Sulfate Amlodipine Carvedilol Ipratropium Levetiracetam Olanzapine Sodium Chloride Symbicort Valproic Acid', 'Mucomyst ASA Benadryl Periactin Colace Ferrous Sulfate Folic Acid Gabapentin Sennosides Albuterol Ipratropium Melatonin MVI Oxycodone Polyethylene Glycol Seroquel Rosuvastatin Valproic Acid Venlafaxine Vitamin C', 'Loratadine', ' Plavix', ' flomax', ' Lisinopril', ' atrovastatin', ' amlodipine', '  Pentoxifylline', ' ASA', ' Donepezil', ' trazodone', ' Metoprolol tartrate.', 'To be determined', 'Robitussin Cough+Chest Cong DM Liquid 5-100 MG/5ML (Dextromethorphan-guaiFENesin) Tylenol Extra Strength Tablet (Acetaminophen) amLODIPine Besylate Tablet 5 MG Morphine Solu Tab 2.5MG Capsaicin Cream 0.025 % Leflunomide Tablet 10 MG Levothy', 'Cetirizine', ' Lactaid', 'Acetaminophen', ' Atenolol', ' Colace', ' Mirtazapine', ' Omeprazole', ' Simvastatin', ' Vitamin D3', 'Ferrex 150 mg', ' Folic Acid 1 mg', ' Furosemide 20 mg', ' Isosorbide Mononoitrate ER 30 mg', ' Lactulose 15 mL', ' Omeprazole 40 mg', ' Potassium Chloride ER  20 MEQ', '  Metoprolol 12.5 mg', ' PreserVision AREDS 2 one capsule', ' Ranolazine ER 1', '000 mg', ' and Sucralf', 'unknown', 'Vitamin D3 5000 units qd Furosemide 20mg qd Olanzapine 2.5mg bid', 'Acetaminophen Tablet 325 MG Give 2 tablet by mouth every 6 hours as needed for Pain. elevated Temp. Phone Active 05/08/2020 05/08/2020 AmLODIPine Besylate Tablet 10 MG Give 1 tablet by mouth one time a day related to ESSENTIAL (PRIMARY) HYP', 'Fluticasone', ' Lasix', ' Sucarafate', ' Ropinrole HCl', 'Olanzapine', ' polyethylene glycol', ' ativan', ' morphine', ' senna', 'Unknown', 'Singulair', ' lopressor', ' pepcid', ' omeprazole', ' lasix', ' albuterol', ' azelastine eye gtts', ' calcium', ' eliquis', ' prozac', ' terazosin', ' magnesium oxide', ' potassium', 'aldactone', ' aspirin', ' tylenol', ' spiriva', 'Lexapro', ' famotidine', ' Namenda', ' Seroquel', ' simvastatin', ' Trazodone; Tamsulosin; Docusate sodium; Polyethylene glycol; Celebrex; Acetaminophen', 'Metoprolol succ ER 50mg 1 tab PO daily Omeprazole DR 20mg 1 cap PO daily Amlodipine besylate 5mg 1 tab PO daily Aspirin 81mg 1 tab PO daily Carbamazepine ER 100mg 1 tab PO TID Docusate 100mg 1 cap PO daily Multivitamin 1 tab PO daily Olmesa', 'Avorstatin Aspirin Oxycodone', 'Norco 5/325 1 tablet every 6 hours as needed. Warfarin 4mg ', ' 2 tablets orally Monday and Friday Torsemide 100mg', ' 1/2 tablet orally once a day Sabcubitril-Valsartan 24/26mg 1/4 tablet orally twice a day Gabapentin 300mg', ' tablet once daily Ca', 'Acetaminophen Tablet 325 MG', ' Enulose Solution 10 GM/15ML (Lactulose Encephalopathy)', ' HYDROcodone-Acetaminophen Tablet 5-325 MG', ' Milk of Magnesia Suspension 400 MG/5ML (Magnesium Hydroxide', ' Potassium Chloride ER Tablet Extended Release 20 ME', 'Lorazepam', ' pantoprazole', ' miralax', ' senna plus', ' carbodopa-levodopa', ' metoprolol', ' mirtazipine', ' quetiapine', 'alprazolam', ' cilostazol', ' advair', ' lamotrigine', ' ', 'losartan', 'omprazole', 'simvastatin', 'Vit D3', ' Miralax', ' Spironolactone', ' Tramadol', ' Metoprolol Succinate', ' MOM', ' Ferrous Gluconate', '  Ondansetron', ' Nitroglycerin Sublingual PRN', ' PreserVision AREDS', ' Fluticasone Propiona ...
